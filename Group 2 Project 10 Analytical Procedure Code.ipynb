# %% [markdown]
# ## Connect to the Database

# %%
import pandas as pd
import psycopg, os
from sqlalchemy import create_engine

# %%
print('Connecting to the PostgreSQL database...') 
conn = psycopg.connect(
    host="localhost",
    port='5432',
    dbname="5310 ETL",
    user="postgres",
    password="123")
cur = conn.cursor()
# Out:
# Connecting to the PostgreSQL database...

# %%
engine = create_engine('postgresql+psycopg2://postgres:123@localhost:5432/5310 ETL')
connection = engine.connect()

# %% [markdown]
# ## Analytical Procedure

# %% [markdown]
# ### 1 - What is the total sales profit of each store in 1998? Rank all stores by total sales profit.

# %%
query1 = """
SELECT 
    RANK() OVER (ORDER BY SUM((s.store_sales - s.store_cost) * s.unit_sales) DESC) AS rank,
    st.store_name AS name,
    st.store_id AS id,
    st.store_type AS type,
    COUNT(e.employee_id) AS num_employees,
    SUM((s.store_sales - s.store_cost) * s.unit_sales) AS total_sales_profit
FROM 
    sales s
JOIN 
    store st ON s.store_id = st.store_id
JOIN 
    employee e ON st.store_id = e.store_id
JOIN 
    time_by_day t ON s.time_id = t.time_id
WHERE 
    t.the_date BETWEEN '1998-01-01' AND '1998-12-31'
GROUP BY 
    st.store_id
ORDER BY 
    total_sales_profit DESC;
"""
cur.execute(query1)
result1 = cur.fetchall()
column_titles = [desc[0] for desc in cur.description]
print(column_titles)
for row in result1:
    print(row)
# Out:
# ['rank', 'name', 'id', 'type', 'num_employees', 'total_sales_profit']
# (1, 'Store 7', 8, 'Supermarket', 907368, Decimal('12242167.6454'))
# (2, 'Store 10', 12, 'Supermarket', 882376, Decimal('11726775.3010'))
# (3, 'Store 16', 19, 'Supermarket', 861878, Decimal('11572479.3588'))
# (4, 'Store 14', 17, 'Small Grocery', 833018, Decimal('11172398.4032'))
# (5, 'Store 11', 13, 'Supermarket', 835682, Decimal('11057971.3892'))
# (6, 'Store 18', 21, 'Mid-Size Grocery', 813260, Decimal('10653025.0520'))
# (7, 'Store 13', 15, 'Deluxe Supermarket', 525822, Decimal('7020630.0904'))
# (8, 'Store 14', 16, 'Small Grocery', 512368, Decimal('6874119.0746'))
# (9, 'Store 9', 11, 'Mid-Size Grocery', 497364, Decimal('6686579.7076'))
# (10, 'Store 3', 3, 'Supermarket', 498550, Decimal('6622934.2205'))
# (11, 'Store 6', 7, 'Gourmet Supermarket', 496860, Decimal('6592866.5075'))
# (12, 'Store 21', 24, 'Deluxe Supermarket', 473494, Decimal('6476568.0066'))
# (13, 'Store 8', 10, 'Deluxe Supermarket', 489676, Decimal('6413024.4236'))
# (14, 'Store 1', 1, 'Supermarket', 479440, Decimal('6407064.4950'))
# (15, 'Store 4', 4, 'Gourmet Supermarket', 384642, Decimal('5104302.9975'))
# (16, 'Store 6', 6, 'Gourmet Supermarket', 371688, Decimal('4840056.1518'))
# (17, 'Store 7', 9, 'Supermarket', 73227, Decimal('966618.1938'))
# (18, 'Store 15', 18, 'Supermarket', 59907, Decimal('813086.6783'))
# (19, 'Store 20', 23, 'Mid-Size Grocery', 58558, Decimal('792009.4463'))
# (20, 'Store 17', 20, 'Deluxe Supermarket', 56715, Decimal('774695.1795'))
# (21, 'Store 2', 2, 'Small Grocery', 9696, Decimal('37705.2592'))
# (22, 'Store 5', 5, 'Small Grocery', 9086, Decimal('33737.6760'))
# (23, 'Store 19', 22, 'Deluxe Supermarket', 5404, Decimal('22280.0132'))
# (24, 'Store 12', 14, 'Deluxe Supermarket', 5072, Decimal('18856.6224'))

# %% [markdown]
# ### 2 - What is the total average sales for each region in 1998? Rank regions by average sales.

# %%
query2 = """
SELECT 
    RANK() OVER (ORDER BY AVG(s.store_sales) DESC) AS rank,
    r.region_id AS id,
    r.sales_region AS name,
    AVG(s.store_sales) AS average_sales
FROM 
    sales s
JOIN 
    store st ON s.store_id = st.store_id
JOIN 
    sales_region r ON st.region_id = r.region_id
JOIN 
    time_by_day t ON s.time_id = t.time_id
WHERE 
    t.the_date BETWEEN '1998-01-01' AND '1998-12-31'
GROUP BY 
    r.region_id
ORDER BY 
    average_sales DESC;
"""
cur.execute(query2)
result2 = cur.fetchall()
column_titles = [desc[0] for desc in cur.description]
print(column_titles)
for row in result2:
    print(row)
# Out:
# ['rank', 'id', 'name', 'average_sales']
# (1, 3, 'South West', Decimal('6.6634388958370556'))
# (2, 1, 'Central West', Decimal('6.6539358355282411'))
# (3, 7, 'Mexico South', Decimal('6.6019334008609775'))
# (4, 6, 'North West', Decimal('6.5876473374819664'))
# (5, 2, 'Mexico Central', Decimal('6.5621974125741300'))
# (6, 4, 'Mexico West', Decimal('6.1585081853816002'))
# (7, 5, 'Canada West', Decimal('5.7777802842318971'))

# %% [markdown]
# ### 3 - What is the total sales profit of each region in 1998? Rank all regions by total sales profit.

# %%
query3 = """

SELECT 
    sr.sales_region AS region,
    sr.region_id,
    st.store_id,
    st.store_name,
    st.store_type,
    MAX((s.store_sales - s.store_cost) * s.unit_sales) AS total_sales_profit
FROM 
    sales s
JOIN 
    store st ON s.store_id = st.store_id
JOIN 
    sales_region sr ON st.region_id = sr.region_id
JOIN 
    time_by_day t ON s.time_id = t.time_id
WHERE 
    t.the_date >= '1998-01-01' AND t.the_date <= '1998-12-31'
GROUP BY 
    sr.sales_region, sr.region_id, st.store_id, st.store_name, st.store_type
ORDER BY 
    sr.sales_region, total_sales_profit DESC;
    
"""
cur.execute(query3)
result3 = cur.fetchall()
column_titles = [desc[0] for desc in cur.description]
print(column_titles)
for row in result3:
    print(row)
# Out:
# ['region', 'region_id', 'store_id', 'store_name', 'store_type', 'total_sales_profit']
# ('Canada West', 5, 23, 'Store 20', 'Mid-Size Grocery', Decimal('63.6500'))
# ('Canada West', 5, 22, 'Store 19', 'Deluxe Supermarket', Decimal('24.1569'))
# ('Central West', 1, 16, 'Store 14', 'Small Grocery', Decimal('67.7925'))
# ('Central West', 1, 6, 'Store 6', 'Gourmet Supermarket', Decimal('67.4475'))
# ('Central West', 1, 8, 'Store 7', 'Supermarket', Decimal('65.1575'))
# ('Mexico Central', 2, 4, 'Store 4', 'Gourmet Supermarket', Decimal('89.2440'))
# ('Mexico Central', 2, 21, 'Store 18', 'Mid-Size Grocery', Decimal('69.4750'))
# ('Mexico Central', 2, 11, 'Store 9', 'Mid-Size Grocery', Decimal('68.6550'))
# ('Mexico Central', 2, 12, 'Store 10', 'Supermarket', Decimal('68.1375'))
# ('Mexico Central', 2, 24, 'Store 21', 'Deluxe Supermarket', Decimal('65.8275'))
# ('Mexico Central', 2, 14, 'Store 12', 'Deluxe Supermarket', Decimal('23.0346'))
# ('Mexico South', 7, 10, 'Store 8', 'Deluxe Supermarket', Decimal('67.6600'))
# ('Mexico West', 4, 1, 'Store 1', 'Supermarket', Decimal('65.7225'))
# ('Mexico West', 4, 5, 'Store 5', 'Small Grocery', Decimal('27.2688'))
# ('North West', 6, 19, 'Store 16', 'Supermarket', Decimal('85.2624'))
# ('North West', 6, 13, 'Store 11', 'Supermarket', Decimal('75.5136'))
# ('North West', 6, 15, 'Store 13', 'Deluxe Supermarket', Decimal('68.4825'))
# ('North West', 6, 18, 'Store 15', 'Supermarket', Decimal('68.1375'))
# ('North West', 6, 3, 'Store 3', 'Supermarket', Decimal('68.1375'))
# ('North West', 6, 20, 'Store 17', 'Deluxe Supermarket', Decimal('67.1500'))
# ('North West', 6, 2, 'Store 2', 'Small Grocery', Decimal('24.7158'))
# ('South West', 3, 7, 'Store 6', 'Gourmet Supermarket', Decimal('71.3952'))
# ('South West', 3, 17, 'Store 14', 'Small Grocery', Decimal('68.6550'))
# ('South West', 3, 9, 'Store 7', 'Supermarket', Decimal('68.1375'))

# %% [markdown]
# ### 4 - Which promotion achieved the greatest revenue in 1998? Rank promotions according to revenue.

# %%
query4 = """ 

SELECT
    RANK() OVER (ORDER BY SUM(s.store_sales * s.unit_sales) DESC) AS rank,
    p.promotion_id,
    p.promotion_name,
    SUM(s.store_sales * s.unit_sales) AS revenue
FROM
    sales s
JOIN
    promotion p ON s.promotion_id = p.promotion_id
JOIN
    time_by_day t ON s.time_id = t.time_id
WHERE
    t.the_date >= '1998-01-01' AND t.the_date <= '1998-12-31'
GROUP BY
    p.promotion_id, p.promotion_name
ORDER BY
    revenue DESC;
"""
cur.execute(query4)
result4 = cur.fetchall()
column_titles = [desc[0] for desc in cur.description]
print(column_titles)
for row in result4:
    print(row)
# Out:
# ['rank', 'promotion_id', 'promotion_name', 'revenue']
# (1, 0, '0', Decimal('2619231.98'))
# (2, 1182, 'Weekend Markdown', Decimal('16551.24'))
# (3, 549, 'Save-It Sale', Decimal('15852.17'))
# (4, 1005, 'Bag Stuffers', Decimal('12577.39'))
# (5, 619, 'Money Savers', Decimal('12427.93'))
# (6, 1328, 'Double Down Sale', Decimal('12080.94'))
# (7, 1168, 'Two Day Sale', Decimal('11731.72'))
# (8, 626, 'Sale Winners', Decimal('11717.42'))
# (9, 1023, 'I Cant Believe It Sale', Decimal('11504.84'))
# (10, 1255, 'Sales Days', Decimal('11403.57'))
# (11, 462, 'Go For It', Decimal('11322.73'))
# (12, 622, 'Shelf Clearing Days', Decimal('11235.33'))
# (13, 460, 'One Day Sale', Decimal('11152.83'))
# (14, 1019, 'Price Slashers', Decimal('10967.97'))
# (15, 1485, 'Super Savers', Decimal('10549.10'))
# (16, 450, 'Price Winners', Decimal('10454.11'))
# (17, 470, 'Dimes Off', Decimal('10095.73'))
# (18, 1008, 'Price Savers', Decimal('9904.65'))
# (19, 1336, 'Super Duper Savers', Decimal('8920.37'))
# (20, 1171, 'Unbeatable Price Savers', Decimal('8782.99'))
# (21, 785, 'Three for One', Decimal('8746.14'))
# (22, 703, 'Coupon Spectacular', Decimal('8665.41'))
# (23, 528, 'One Day Sale', Decimal('8407.42'))
# (24, 700, 'Go For It', Decimal('8400.87'))
# (25, 693, 'Dollar Cutters', Decimal('7957.81'))
# (26, 781, 'Super Savers', Decimal('7885.64'))
# (27, 1248, 'Two for One', Decimal('7826.31'))
# (28, 313, 'Saving Days', Decimal('7806.23'))
# (29, 1876, 'One Day Sale', Decimal('7702.98'))
# (30, 467, 'Tip Top Savings', Decimal('7521.81'))
# (31, 861, 'Free For All', Decimal('7485.70'))
# (32, 764, 'Price Savers', Decimal('7450.54'))
# (33, 466, 'Price Destroyers', Decimal('7436.38'))
# (34, 227, 'Shelf Clearing Days', Decimal('7414.82'))
# (35, 696, 'Two Day Sale', Decimal('7341.48'))
# (36, 291, 'Shelf Emptiers', Decimal('7129.22'))
# (37, 297, 'Weekend Markdown', Decimal('7125.05'))
# (38, 859, 'Green Light Days', Decimal('7020.88'))
# (39, 704, 'Price Destroyers', Decimal('6811.44'))
# (40, 1241, 'Big Time Discounts', Decimal('6486.84'))
# (41, 299, 'Green Light Days', Decimal('6474.76'))
# (42, 1332, 'Two for One', Decimal('6469.41'))
# (43, 686, 'Two Day Sale', Decimal('6418.30'))
# (44, 1486, 'Price Slashers', Decimal('6370.80'))
# (45, 783, 'Big Time Discounts', Decimal('6312.56'))
# (46, 1871, 'Sales Days', Decimal('6204.68'))
# (47, 1497, 'Price Smashers', Decimal('6196.31'))
# (48, 453, 'Two Day Sale', Decimal('6173.33'))
# (49, 1487, 'Price Cutters', Decimal('6155.33'))
# (50, 1496, 'Money Savers', Decimal('6099.56'))
# (51, 699, 'Weekend Markdown', Decimal('6055.71'))
# (52, 621, 'Big Time Savings', Decimal('6036.20'))
# (53, 451, 'Big Time Discounts', Decimal('6017.82'))
# (54, 545, 'Two for One', Decimal('5966.87'))
# (55, 1489, 'Bye Bye Baby', Decimal('5813.28'))
# (56, 625, 'Big Promo', Decimal('5755.74'))
# (57, 458, 'Price Winners', Decimal('5748.23'))
# (58, 1792, 'Green Light Special', Decimal('5682.05'))
# (59, 1484, 'I Cant Believe It Sale', Decimal('5642.74'))
# (60, 1331, 'Saving Days', Decimal('5639.23'))
# (61, 606, 'Two Day Sale', Decimal('5585.46'))
# (62, 1493, 'Super Duper Savers', Decimal('5343.50'))
# (63, 615, 'Sales Days', Decimal('5322.43'))
# (64, 1339, 'Bag Stuffers', Decimal('5311.72'))
# (65, 461, 'Price Savers', Decimal('5289.70'))
# (66, 233, 'Money Savers', Decimal('5273.95'))
# (67, 1323, 'Save-It Sale', Decimal('5258.66'))
# (68, 1495, 'Super Duper Savers', Decimal('5251.28'))
# (69, 1014, 'Double Down Sale', Decimal('5221.07'))
# (70, 455, 'Pick Your Savings', Decimal('5161.36'))
# (71, 695, 'Shelf Emptiers', Decimal('5147.35'))
# (72, 536, 'Bye Bye Baby', Decimal('5144.58'))
# (73, 689, 'Price Smashers', Decimal('5103.62'))
# (74, 1010, 'High Roller Savings', Decimal('5049.11'))
# (75, 449, 'Two for One', Decimal('5001.62'))
# (76, 1498, 'Double Down Sale', Decimal('4984.96'))
# (77, 1324, 'Dollar Cutters', Decimal('4973.22'))
# (78, 618, 'One Day Sale', Decimal('4920.96'))
# (79, 1330, 'Weekend Markdown', Decimal('4817.70'))
# (80, 1893, 'Price Savers', Decimal('4809.18'))
# (81, 290, 'High Roller Savings', Decimal('4804.74'))
# (82, 1170, 'Big Time Savings', Decimal('4729.76'))
# (83, 609, 'Price Winners', Decimal('4707.60'))
# (84, 304, 'Two Day Sale', Decimal('4692.78'))
# (85, 1001, 'Big Time Discounts', Decimal('4652.25'))
# (86, 1892, 'Sale Winners', Decimal('4639.09'))
# (87, 1246, 'Savings Galore', Decimal('4593.93'))
# (88, 694, 'Price Smashers', Decimal('4588.69'))
# (89, 617, 'Best Savings', Decimal('4576.91'))
# (90, 688, 'Super Duper Savers', Decimal('4515.15'))
# (91, 1015, 'Free For All', Decimal('4515.12'))
# (92, 1322, 'Tip Top Savings', Decimal('4491.65'))
# (93, 607, 'Dimes Off', Decimal('4459.20'))
# (94, 1888, 'Price Winners', Decimal('4357.84'))
# (95, 296, 'Unbeatable Price Savers', Decimal('4352.85'))
# (96, 624, 'Pick Your Savings', Decimal('4336.71'))
# (97, 614, 'Three for One', Decimal('4334.08'))
# (98, 1479, 'Green Light Special', Decimal('4305.08'))
# (99, 1872, 'Tip Top Savings', Decimal('4255.50'))
# (100, 55, 'Price Slashers', Decimal('4219.40'))
# (101, 1337, 'Price Winners', Decimal('4213.60'))
# (102, 849, 'Price Slashers', Decimal('4188.46'))
# (103, 58, 'Price Winners', Decimal('4138.14'))
# (104, 54, 'Two Day Sale', Decimal('4097.27'))
# (105, 1882, 'Dollar Days', Decimal('3984.19'))
# (106, 1016, 'Big Time Savings', Decimal('3965.13'))
# (107, 1317, 'Free For All', Decimal('3902.55'))
# (108, 782, 'Price Slashers', Decimal('3887.24'))
# (109, 305, 'Price Winners', Decimal('3882.74'))
# (110, 629, 'Sales Galore', Decimal('3881.04'))
# (111, 848, 'Shelf Clearing Days', Decimal('3826.71'))
# (112, 220, 'High Roller Savings', Decimal('3806.14'))
# (113, 1475, 'Double Down Sale', Decimal('3756.29'))
# (114, 1244, 'Big Promo', Decimal('3724.38'))
# (115, 847, 'Sale Winners', Decimal('3713.47'))
# (116, 59, 'Price Winners', Decimal('3634.25'))
# (117, 1175, 'Sales Galore', Decimal('3593.88'))
# (118, 75, 'Save-It Sale', Decimal('3542.49'))
# (119, 544, 'Saving Days', Decimal('3541.48'))
# (120, 697, 'Free For All', Decimal('3513.23'))
# (121, 1012, 'Save-It Sale', Decimal('3512.37'))
# (122, 212, 'Go For It', Decimal('3511.65'))
# (123, 1879, 'Price Winners', Decimal('3497.86'))
# (124, 701, 'Super Wallet Savers', Decimal('3492.56'))
# (125, 773, 'Super Savers', Decimal('3477.11'))
# (126, 1242, 'Tip Top Savings', Decimal('3437.35'))
# (127, 862, 'Wallet Savers', Decimal('3425.83'))
# (128, 776, 'Wallet Savers', Decimal('3387.42'))
# (129, 547, 'Two Day Sale', Decimal('3312.22'))
# (130, 777, 'Money Savers', Decimal('3304.93'))
# (131, 707, 'I Cant Believe It Sale', Decimal('3284.78'))
# (132, 224, 'Dollar Cutters', Decimal('3279.09'))
# (133, 1180, 'Dimes Off', Decimal('3260.53'))
# (134, 1798, 'Big Time Discounts', Decimal('3260.07'))
# (135, 863, 'Go For It', Decimal('3222.47'))
# (136, 767, 'Go For It', Decimal('3216.43'))
# (137, 850, 'Go For It', Decimal('3189.26'))
# (138, 537, 'Big Time Discounts', Decimal('3185.36'))
# (139, 62, 'Sales Days', Decimal('3181.83'))
# (140, 527, 'Pick Your Savings', Decimal('3176.83'))
# (141, 550, 'Big Promo', Decimal('3144.77'))
# (142, 73, 'Shelf Clearing Days', Decimal('3140.37'))
# (143, 543, 'Fantastic Discounts', Decimal('3136.64'))
# (144, 1245, 'Dollar Cutters', Decimal('3134.74'))
# (145, 541, 'Price Winners', Decimal('3130.66'))
# (146, 539, 'High Roller Savings', Decimal('3117.54'))
# (147, 1160, 'Dollar Cutters', Decimal('3107.73'))
# (148, 690, 'Bye Bye Baby', Decimal('3101.98'))
# (149, 1890, 'Best Savings', Decimal('3084.94'))
# (150, 692, 'Super Savers', Decimal('3068.11'))
# (151, 1878, 'Save-It Sale', Decimal('3061.93'))
# (152, 1166, 'Weekend Markdown', Decimal('3059.45'))
# (153, 63, 'Dollar Cutters', Decimal('3025.56'))
# (154, 768, 'Best Savings', Decimal('3024.87'))
# (155, 1873, 'Go For It', Decimal('2980.10'))
# (156, 214, 'Coupon Spectacular', Decimal('2977.95'))
# (157, 548, 'Sale Winners', Decimal('2942.29'))
# (158, 533, 'Shelf Clearing Days', Decimal('2910.97'))
# (159, 222, 'Two for One', Decimal('2905.16'))
# (160, 844, 'Weekend Markdown', Decimal('2873.20'))
# (161, 787, 'Shelf Clearing Days', Decimal('2850.85'))
# (162, 312, 'Price Destroyers', Decimal('2835.45'))
# (163, 687, 'Price Cutters', Decimal('2747.79'))
# (164, 1257, 'Price Winners', Decimal('2727.57'))
# (165, 1251, 'Go For It', Decimal('2716.04'))
# (166, 1252, 'Price Destroyers', Decimal('2692.89'))
# (167, 534, 'Mystery Sale', Decimal('2626.81'))
# (168, 301, 'Price Cutters', Decimal('2456.07'))
# (169, 1177, 'Super Duper Savers', Decimal('2432.64'))
# (170, 538, 'Saving Days', Decimal('2361.89'))
# (171, 854, 'Price Destroyers', Decimal('2341.29'))
# (172, 853, 'Big Time Discounts', Decimal('2308.63'))
# (173, 1577, 'Savings Galore', Decimal('2123.45'))
# (174, 452, 'Two for One', Decimal('1918.83'))
# (175, 463, 'I Cant Believe It Sale', Decimal('1791.58'))
# (176, 465, 'Savings Galore', Decimal('1790.19'))
# (177, 1800, 'Save-It Sale', Decimal('1736.49'))
# (178, 457, 'Price Destroyers', Decimal('1729.54'))
# (179, 691, 'Three for One', Decimal('1722.82'))
# (180, 1797, 'Sale Winners', Decimal('1687.81'))
# (181, 1568, 'Green Light Special', Decimal('1662.88'))
# (182, 1566, 'I Cant Believe It Sale', Decimal('1506.45'))
# (183, 1811, 'Tip Top Savings', Decimal('1458.79'))
# (184, 1559, 'Save-It Sale', Decimal('1420.26'))
# (185, 1569, 'Sales Days', Decimal('1330.53'))
# (186, 1570, 'Super Duper Savers', Decimal('1322.46'))
# (187, 1572, 'Shelf Clearing Days', Decimal('1298.81'))
# (188, 1807, 'Double Your Savings', Decimal('1285.41'))
# (189, 459, 'Dollar Cutters', Decimal('1198.44'))
# (190, 1814, 'Super Duper Savers', Decimal('1173.53'))
# (191, 1564, 'Double Your Savings', Decimal('1150.63'))
# (192, 1558, 'Save-It Sale', Decimal('1142.59'))
# (193, 698, 'Coupon Spectacular', Decimal('1110.91'))
# (194, 1794, 'Super Duper Savers', Decimal('1106.48'))
# (195, 1715, 'Sale Winners', Decimal('471.68'))
# (196, 1731, 'Coupon Spectacular', Decimal('426.80'))
# (197, 143, 'Coupon Spectacular', Decimal('381.21'))
# (198, 374, 'Super Duper Savers', Decimal('326.77'))
# (199, 1089, 'I Cant Believe It Sale', Decimal('326.22'))
# (200, 1714, 'Pick Your Savings', Decimal('307.71'))
# (201, 1083, 'You Save Days', Decimal('294.18'))
# (202, 1726, 'Bag Stuffers', Decimal('286.08'))
# (203, 1093, 'Price Winners', Decimal('285.96'))
# (204, 145, 'Fantastic Discounts', Decimal('251.92'))
# (205, 379, 'Two for One', Decimal('223.30'))
# (206, 155, 'One Day Sale', Decimal('216.53'))
# (207, 139, 'Sale Winners', Decimal('213.11'))
# (208, 1100, 'One Day Sale', Decimal('209.70'))
# (209, 373, 'Saving Days', Decimal('209.07'))
# (210, 1719, 'Big Time Savings', Decimal('202.60'))
# (211, 1712, 'Bye Bye Baby', Decimal('190.14'))
# (212, 137, 'Double Your Savings', Decimal('189.97'))
# (213, 370, 'Price Winners', Decimal('189.02'))
# (214, 375, 'Best Savings', Decimal('187.79'))
# (215, 140, 'Double Down Sale', Decimal('187.05'))
# (216, 138, 'Two Day Sale', Decimal('186.33'))
# (217, 372, 'Sale Winners', Decimal('184.56'))
# (218, 378, 'Double Down Sale', Decimal('183.54'))
# (219, 149, 'Two Day Sale', Decimal('178.08'))
# (220, 1099, 'Super Savers', Decimal('172.52'))
# (221, 1081, 'Money Savers', Decimal('166.29'))
# (222, 1084, 'Savings Galore', Decimal('165.03'))
# (223, 1090, 'Fantastic Discounts', Decimal('164.47'))
# (224, 383, 'Free For All', Decimal('158.23'))
# (225, 133, 'Big Promo', Decimal('147.50'))
# (226, 154, 'Dollar Cutters', Decimal('142.27'))
# (227, 135, 'Super Duper Savers', Decimal('139.06'))
# (228, 1733, 'Weekend Markdown', Decimal('138.46'))
# (229, 381, 'Best Savings', Decimal('128.63'))
# (230, 1096, 'Weekend Markdown', Decimal('123.41'))
# (231, 387, 'Price Winners', Decimal('106.97'))
# (232, 369, 'Dollar Cutters', Decimal('104.90'))
# (233, 1085, 'Sales Galore', Decimal('93.89'))
# (234, 377, 'Mystery Sale', Decimal('86.80'))
# (235, 1094, 'Green Light Special', Decimal('85.79'))
# (236, 389, 'Dollar Cutters', Decimal('83.99'))
# (237, 1723, 'Dollar Days', Decimal('79.12'))
# (238, 382, 'Coupon Spectacular', Decimal('75.37'))
# (239, 1092, 'Pick Your Savings', Decimal('74.57'))
# (240, 152, 'Sales Days', Decimal('72.08'))
# (241, 388, 'Super Wallet Savers', Decimal('70.65'))

# %% [markdown]
# ### 5 - What is the monthly sales revenue in 1998?

# %%
query5 =  """

SELECT
    EXTRACT(MONTH FROM t.the_date) AS month,
    SUM(e.amount * c.conversion_ratio) AS total_expense_in_usd
FROM
    expense e
JOIN
    time_by_day t ON e.exp_time_id = t.time_id
JOIN
    currency c ON t.the_date >= c.date AND t.the_date < c.date + INTERVAL '1 MONTH'
WHERE
    EXTRACT(YEAR FROM t.the_date) = 1998
GROUP BY
    EXTRACT(MONTH FROM t.the_date)
ORDER BY
    month;
"""
cur.execute(query5)
rows = cur.fetchall()
column_titles = [desc[0] for desc in cur.description]
print(column_titles)
for row in rows:
    print(row)
# Out:
# ['month', 'total_expense_in_usd']
# (Decimal('1'), 139328.028)
# (Decimal('2'), 139328.028)
# (Decimal('3'), 139328.028)
# (Decimal('4'), 139328.028)
# (Decimal('5'), 138553.9834)
# (Decimal('6'), 137779.93880000003)
# (Decimal('7'), 137975.73880000008)
# (Decimal('8'), 137980.01080000008)
# (Decimal('9'), 138158.01080000008)
# (Decimal('10'), 138158.01080000008)
# (Decimal('11'), 138158.01080000008)
# (Decimal('12'), 138158.01080000008)

# %%
import csv
with open('expenses_1998.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(column_titles)
    for row in rows:
        writer.writerow(row)

print('csv is exported')
# Out:
# csv is exported

# %% [markdown]
# ### 6 - What is the monthly expense in USD in 1998?

# %%
query6 =  """
SELECT
    t.month_of_year AS month,
    SUM(s.store_sales * s.unit_sales) AS total_sales_revenue_in_USD
FROM
    sales s
JOIN
    time_by_day t ON s.time_id = t.time_id
WHERE
    t.the_date >= '1998-01-01' AND t.the_date <= '1998-12-31'
GROUP BY
    t.month_of_year
ORDER BY
    t.month_of_year;
"""
cur.execute(query6)
rows = cur.fetchall()
column_titles = [desc[0] for desc in cur.description]
print(column_titles)
for row in rows:
    print(row)
# Out:
# ['month', 'total_sales_revenue_in_usd']
# (1, Decimal('325810.58'))
# (2, Decimal('313505.86'))
# (3, Decimal('326385.44'))
# (4, Decimal('314083.08'))
# (5, Decimal('315537.67'))
# (6, Decimal('321986.37'))
# (7, Decimal('329248.84'))
# (8, Decimal('312615.87'))
# (9, Decimal('336878.16'))
# (10, Decimal('307381.33'))
# (11, Decimal('378981.16'))

# %%
with open('sales_revenue_1998.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(column_titles)
    for row in rows:
        writer.writerow(row)

print('csv is exported')
# Out:
# csv is exported

# %% [markdown]
# ### 7 - Which product has the highest sales profit in 1998? Rank products by sales profit.

# %%
query7 =  """ 
SELECT
    ROW_NUMBER() OVER (ORDER BY SUM((s.store_sales - s.store_cost) * s.unit_sales) DESC) AS rank,
    p.product_name AS name,
    p.product_id AS id,
    SUM((s.store_sales - s.store_cost) * s.unit_sales) AS total_sales_profit
FROM
    sales s
JOIN
    time_by_day t ON s.time_id = t.time_id
JOIN
    product p ON s.product_id = p.product_id
WHERE
    t.the_date >= '1998-01-01' AND t.the_date <= '1998-12-31'
GROUP BY
    p.product_id, p.product_name
ORDER BY
    total_sales_profit DESC;
"""
cur.execute(query7)
rows = cur.fetchall()
column_titles = [desc[0] for desc in cur.description]
print(column_titles)
for row in rows:
    print(row)
# Out:
# ['rank', 'name', 'id', 'total_sales_profit']
# (1, 'Great Pumpernickel Bread', 274, Decimal('3166.3214'))
# (2, 'Super Extra Chunky Peanut Butter', 309, Decimal('2988.5634'))
# (3, 'Horatio Frosted Cookies', 1180, Decimal('2971.0200'))
# (4, 'High Top New Potatos', 175, Decimal('2969.1200'))
# (5, 'Hilltop Mint Mouthwash', 1380, Decimal('2961.5582'))
# (6, 'Even Better Large Curd Cottage Cheese', 993, Decimal('2946.4235'))
# (7, 'Fabulous Strawberry Drink', 941, Decimal('2924.2640'))
# (8, 'Better Chicken Soup', 330, Decimal('2908.2258'))
# (9, 'Horatio Low Fat Chips', 1178, Decimal('2886.8616'))
# (10, 'Modell Rye Bread', 1525, Decimal('2881.2009'))
# (11, 'Carrington Turkey TV Dinner', 1345, Decimal('2878.2752'))
# (12, 'Carlson Strawberry Yogurt', 372, Decimal('2876.0674'))
# (13, 'Great Rye Bread', 276, Decimal('2838.6440'))
# (14, 'Horatio Fudge Cookies', 1161, Decimal('2833.8024'))
# (15, 'Moms Foot-Long Hot Dogs', 379, Decimal('2827.1705'))
# (16, 'Fort West BBQ Potato Chips', 1467, Decimal('2817.9276'))
# (17, 'Hermanos Green Pepper', 1428, Decimal('2812.4346'))
# (18, 'Nationeel Raspberry Fruit Roll', 868, Decimal('2804.7510'))
# (19, 'Horatio No Salt Popcorn', 1168, Decimal('2802.0082'))
# (20, 'Imagine Frozen Carrots', 717, Decimal('2799.5464'))
# (21, 'Denny Frying Pan', 155, Decimal('2786.9007'))
# (22, 'Horatio Sugar Cookies', 1159, Decimal('2783.0250'))
# (23, 'Carlson Head Cheese', 362, Decimal('2782.6921'))
# (24, 'Imagine Popsicles', 731, Decimal('2777.3757'))
# (25, 'Medalist Rice Medly', 265, Decimal('2766.5596'))
# (26, 'Booker Strawberry Yogurt', 1310, Decimal('2766.4980'))
# (27, 'Big Time Beef TV Dinner', 409, Decimal('2765.7385'))
# (28, 'Tell Tale Fresh Lima Beans', 502, Decimal('2737.9290'))
# (29, 'Thresher Spicy Mints', 880, Decimal('2704.3580'))
# (30, 'Skinner Mango Drink', 1251, Decimal('2704.0814'))
# (31, 'Golden Frozen Cauliflower', 105, Decimal('2695.0656'))
# (32, 'Red Wing Plastic Knives', 446, Decimal('2694.3375'))
# (33, 'Gerolli Extra Lean Hamburger', 1413, Decimal('2691.4940'))
# (34, 'Cormorant Paper Cups', 762, Decimal('2681.7230'))
# (35, 'Even Better Havarti Cheese', 988, Decimal('2680.5333'))
# (36, 'Hermanos Lemons', 1448, Decimal('2672.3050'))
# (37, 'Denny Paper Towels', 148, Decimal('2669.6470'))
# (38, 'Carlson 2% Milk', 367, Decimal('2652.4349'))
# (39, 'High Top Corn on the Cob', 172, Decimal('2650.6548'))
# (40, 'Super Strawberry Jam', 306, Decimal('2632.9644'))
# (41, 'Great White Bread', 275, Decimal('2631.1074'))
# (42, 'Good White Zinfandel Wine', 272, Decimal('2630.3743'))
# (43, 'Denny 75 Watt Lightbulb', 141, Decimal('2625.2793'))
# (44, 'Consolidated Childrens Aspirin', 744, Decimal('2622.3197'))
# (45, 'Medalist Spaghetti', 263, Decimal('2621.7340'))
# (46, 'Faux Products Buffered Aspirin', 123, Decimal('2619.1104'))
# (47, 'Portsmouth Light Beer', 1211, Decimal('2615.7064'))
# (48, 'Giant Large Brown Eggs', 1327, Decimal('2611.3536'))
# (49, 'Cormorant Copper Pot Scrubber', 781, Decimal('2604.3535'))
# (50, 'Tell Tale Cantelope', 519, Decimal('2599.7392'))
# (51, 'Best Oatmeal', 323, Decimal('2598.6100'))
# (52, 'Carrington Frozen Mushroom Pizza', 1342, Decimal('2580.4886'))
# (53, 'Red Wing AAA-Size Batteries', 449, Decimal('2579.2731'))
# (54, 'PigTail Low Fat French Fries', 1024, Decimal('2556.0845'))
# (55, 'Golden Popsicles', 109, Decimal('2554.1095'))
# (56, 'High Quality Scented Toilet Tissue', 1091, Decimal('2552.6980'))
# (57, 'Hilltop Conditioning Shampoo', 1367, Decimal('2552.4429'))
# (58, 'Hermanos New Potatos', 1424, Decimal('2543.7678'))
# (59, 'Hilltop Extra Moisture Shampoo', 1368, Decimal('2541.5160'))
# (60, 'Big Time Apple Cinnamon Waffles', 405, Decimal('2540.0115'))
# (61, 'Nationeel Low Fat Popcorn', 853, Decimal('2538.3736'))
# (62, 'Just Right Rice Soup', 975, Decimal('2532.5480'))
# (63, 'Golden Orange Popsicles', 83, Decimal('2523.5132'))
# (64, 'Lake Potato Salad', 1324, Decimal('2521.1277'))
# (65, 'Gauss Monthly Sports Magazine', 1415, Decimal('2511.1540'))
# (66, 'Super Apple Jam', 305, Decimal('2509.7526'))
# (67, 'BBB Best Apple Preserves', 937, Decimal('2500.4665'))
# (68, 'Big Time Frozen Peas', 419, Decimal('2491.3245'))
# (69, 'Gulf Coast Bubble Gum', 1506, Decimal('2487.6761'))
# (70, 'Ebony Lettuce', 803, Decimal('2486.2383'))
# (71, 'CDR Vegetable Oil', 1540, Decimal('2484.0992'))
# (72, 'Bravo Chicken Soup', 641, Decimal('2481.7688'))
# (73, 'Consolidated 200 MG Ibuprofen', 746, Decimal('2477.9878'))
# (74, 'Colossal Thai Rice', 1202, Decimal('2476.1324'))
# (75, 'Lake Pimento Loaf', 1313, Decimal('2472.6576'))
# (76, 'Plato Pepper', 1236, Decimal('2468.9512'))
# (77, 'Fast Sugar Cookies', 532, Decimal('2466.5445'))
# (78, 'Gorilla 2% Milk', 678, Decimal('2461.9311'))
# (79, 'Tri-State Red Delcious Apples', 1136, Decimal('2460.6843'))
# (80, 'Bravo Fancy Canned Clams', 656, Decimal('2460.6505'))
# (81, 'Nationeel Potato Chips', 847, Decimal('2442.9696'))
# (82, 'Best Choice Sugar Cookies', 221, Decimal('2440.9638'))
# (83, 'Imagine Low Fat French Fries', 708, Decimal('2437.8528'))
# (84, 'Blue Label Canned Peas', 28, Decimal('2436.4774'))
# (85, 'Plato Tomato Sauce', 1231, Decimal('2432.7583'))
# (86, 'Hilltop 200 MG Ibuprofen', 1373, Decimal('2431.5840'))
# (87, 'Horatio Corn Chips', 1157, Decimal('2426.8944'))
# (88, 'Denny 100 Watt Lightbulb', 137, Decimal('2426.4600'))
# (89, 'Cormorant Frying Pan', 777, Decimal('2414.0940'))
# (90, 'Medalist Ravioli', 261, Decimal('2412.7116'))
# (91, 'Golden Frozen Chicken Wings', 111, Decimal('2411.8488'))
# (92, 'Gulf Coast Mints', 1508, Decimal('2409.1470'))
# (93, 'Gorilla Jack Cheese', 668, Decimal('2407.2036'))
# (94, 'Gauss Monthly Computer Magazine', 1417, Decimal('2406.2816'))
# (95, 'High Top Dried Mushrooms', 190, Decimal('2398.8360'))
# (96, 'Club Blueberry Yogurt', 62, Decimal('2391.2054'))
# (97, 'Hermanos Onions', 1427, Decimal('2389.2909'))
# (98, 'Super Oregano', 302, Decimal('2388.1935'))
# (99, 'High Quality Copper Cleaner', 1094, Decimal('2386.2592'))
# (100, 'Nationeel Apple Fruit Roll', 866, Decimal('2382.8674'))
# (101, 'Thresher Tasty Candy Bar', 875, Decimal('2373.0152'))
# (102, 'Hermanos Mixed Nuts', 1454, Decimal('2370.5931'))
# (103, 'High Quality 60 Watt Lightbulb', 1070, Decimal('2370.4434'))
# (104, 'Golden Ice Cream Sandwich', 104, Decimal('2369.7102'))
# (105, 'Quick Seasoned Hamburger', 476, Decimal('2365.9272'))
# (106, 'Ebony Tangerines', 835, Decimal('2360.2172'))
# (107, 'ADJ Rosy Sunglasses', 351, Decimal('2356.4052'))
# (108, 'Colossal Spaghetti', 1201, Decimal('2355.6300'))
# (109, 'Best Choice Fudge Cookies', 223, Decimal('2352.4655'))
# (110, 'Plato Apple Preserves', 1248, Decimal('2347.0506'))
# (111, 'Red Wing Copper Cleaner', 467, Decimal('2343.6834'))
# (112, 'Musial Mints', 1197, Decimal('2343.3192'))
# (113, 'Fast Cheese Crackers', 539, Decimal('2343.0352'))
# (114, 'Tell Tale Almonds', 506, Decimal('2342.1360'))
# (115, 'James Bay Eyeglass Screwdriver', 979, Decimal('2339.0640'))
# (116, 'Tri-State Sweet Peas', 1112, Decimal('2331.0812'))
# (117, 'Carlson Mild Cheddar Cheese', 365, Decimal('2325.3516'))
# (118, 'High Quality Plastic Knives', 1073, Decimal('2325.2655'))
# (119, 'Plato French Roast Coffee', 1226, Decimal('2322.1496'))
# (120, 'Big Time Frozen Corn', 418, Decimal('2320.9252'))
# (121, 'Urban Small Eggs', 390, Decimal('2315.0226'))
# (122, 'Denny Plastic Knives', 135, Decimal('2312.6828'))
# (123, 'Cormorant Room Freshener', 776, Decimal('2310.6989'))
# (124, 'Red Spade Beef Bologna', 65, Decimal('2310.5576'))
# (125, 'Best Choice Cheese Dip', 235, Decimal('2305.8670'))
# (126, 'Ebony Dried Mushrooms', 812, Decimal('2304.6000'))
# (127, 'CDR Decaf Coffee', 1538, Decimal('2301.9020'))
# (128, 'Fabulous Orange Juice', 946, Decimal('2301.4605'))
# (129, 'Excellent Cranberry Juice', 320, Decimal('2299.6692'))
# (130, 'Pleasant Canned Tomatos', 1271, Decimal('2295.5800'))
# (131, 'CDR Regular Coffee', 1539, Decimal('2294.4578'))
# (132, 'Hilltop Angled Toothbrush', 1369, Decimal('2292.8906'))
# (133, 'High Top Garlic', 184, Decimal('2292.8240'))
# (134, 'Lake Sliced Turkey', 1322, Decimal('2290.2720'))
# (135, 'Tell Tale Fuji Apples', 521, Decimal('2289.0780'))
# (136, 'Imagine Fajita French Fries', 711, Decimal('2288.7644'))
# (137, 'Imagine Frozen Pepperoni Pizza', 713, Decimal('2288.7208'))
# (138, 'Red Wing Copper Pot Scrubber', 470, Decimal('2283.4600'))
# (139, 'Bird Call 200 MG Acetominifen', 1063, Decimal('2283.2718'))
# (140, 'PigTail Popsicles', 1047, Decimal('2277.4084'))
# (141, 'Fantastic Bagels', 907, Decimal('2273.5134'))
# (142, 'Excel Monthly Auto Magazine', 789, Decimal('2272.8894'))
# (143, 'Cormorant Toilet Bowl Cleaner', 764, Decimal('2272.7031'))
# (144, 'Tell Tale Golden Delcious Apples', 508, Decimal('2271.9155'))
# (145, 'Pleasant Fancy Canned Anchovies', 1282, Decimal('2270.2624'))
# (146, 'Super Salt', 300, Decimal('2269.8564'))
# (147, 'Top Measure Chablis Wine', 1518, Decimal('2257.0592'))
# (148, 'Hermanos Lettuce', 1430, Decimal('2257.0464'))
# (149, 'Framton Eyeglass Screwdriver', 1290, Decimal('2254.9929'))
# (150, 'Tip Top Scallops', 216, Decimal('2252.0160'))
# (151, 'Big Time Frozen Cauliflower', 416, Decimal('2249.4992'))
# (152, 'Tri-State Corn on the Cob', 1110, Decimal('2246.7200'))
# (153, 'Big Time Frozen Chicken Thighs', 421, Decimal('2245.9825'))
# (154, 'Top Measure Light Wine', 1516, Decimal('2245.5888'))
# (155, 'Imagine Waffles', 712, Decimal('2245.1031'))
# (156, 'Denny AA-Size Batteries', 146, Decimal('2241.3543'))
# (157, 'Great English Muffins', 277, Decimal('2240.0468'))
# (158, 'Sunset AAA-Size Batteries', 1387, Decimal('2238.8350'))
# (159, 'Best Choice Potato Chips', 225, Decimal('2235.3885'))
# (160, 'Skinner Diet Soda', 1254, Decimal('2230.2590'))
# (161, 'Club Jack Cheese', 46, Decimal('2224.1664'))
# (162, 'Gorilla Sharp Cheddar Cheese', 675, Decimal('2223.4306'))
# (163, 'Big Time Frozen Pancakes', 396, Decimal('2221.6680'))
# (164, 'PigTail Frozen Chicken Wings', 1049, Decimal('2216.8737'))
# (165, 'Portsmouth Chardonnay Wine', 1206, Decimal('2211.4239'))
# (166, 'Great Cranberry Muffins', 278, Decimal('2211.3168'))
# (167, 'Tri-State Plums', 1139, Decimal('2204.6310'))
# (168, 'Jumbo Large Eggs', 702, Decimal('2198.3616'))
# (169, 'Nationeel Dried Apples', 865, Decimal('2197.3482'))
# (170, 'Imagine Frozen Cheese Pizza', 714, Decimal('2196.9630'))
# (171, 'Blue Label Chicken Soup', 19, Decimal('2195.2942'))
# (172, 'Booker Blueberry Yogurt', 1311, Decimal('2194.9774'))
# (173, 'Carlson Muenster Cheese', 358, Decimal('2194.7250'))
# (174, 'High Quality Scissors', 1099, Decimal('2192.7996'))
# (175, 'Cormorant C-Size Batteries', 758, Decimal('2192.6146'))
# (176, 'Fast Dried Apples', 554, Decimal('2190.7466'))
# (177, 'Steady 200 MG Ibuprofen', 435, Decimal('2189.3729'))
# (178, 'Just Right Creamed Corn', 955, Decimal('2185.4746'))
# (179, 'Denny Scented Tissue', 150, Decimal('2183.1600'))
# (180, 'Better Regular Ramen Soup', 335, Decimal('2181.6542'))
# (181, 'Faux Products Toothpaste', 116, Decimal('2180.9195'))
# (182, 'Fast Corn Chips', 530, Decimal('2180.0856'))
# (183, 'Club Sharp Cheddar Cheese', 53, Decimal('2180.0790'))
# (184, 'Atomic Bubble Gum', 568, Decimal('2175.5556'))
# (185, 'Red Wing Plastic Forks', 444, Decimal('2174.6417'))
# (186, 'Carlson Blueberry Yogurt', 373, Decimal('2173.3896'))
# (187, 'Sphinx White Bread', 1213, Decimal('2172.0090'))
# (188, 'Nationeel Golden Raisins', 872, Decimal('2169.7956'))
# (189, 'Red Spade Low Fat Bologna', 66, Decimal('2168.5760'))
# (190, 'Big Time Frozen Chicken Wings', 422, Decimal('2163.3549'))
# (191, 'High Top Baby Onion', 189, Decimal('2153.2140'))
# (192, 'Best Choice Golden Raisins', 250, Decimal('2148.1719'))
# (193, 'Hermanos Prepared Salad', 1426, Decimal('2146.1242'))
# (194, 'Bravo Noodle Soup', 645, Decimal('2141.1012'))
# (195, 'Even Better Sharp Cheddar Cheese', 991, Decimal('2135.6075'))
# (196, 'Fort West Apple Fruit Roll', 1493, Decimal('2135.2716'))
# (197, 'BBB Best Strawberry Jelly', 924, Decimal('2134.7010'))
# (198, 'Excellent Mango Drink', 313, Decimal('2132.9115'))
# (199, 'Steady Multi-Symptom Cold Remedy', 439, Decimal('2126.8450'))
# (200, 'Colony Rye Bread', 587, Decimal('2125.1730'))
# (201, 'Ebony Plums', 823, Decimal('2123.3415'))
# (202, 'Tri-State Red Pepper', 1121, Decimal('2117.6253'))
# (203, 'Hilltop 200 MG Acetominifen', 1374, Decimal('2117.0695'))
# (204, 'Gorilla Mild Cheddar Cheese', 676, Decimal('2116.5886'))
# (205, 'Horatio Graham Crackers', 1165, Decimal('2114.6898'))
# (206, 'Good Chablis Wine', 269, Decimal('2113.5280'))
# (207, 'Even Better Strawberry Yogurt', 999, Decimal('2112.0927'))
# (208, 'Plato Apple Jelly', 1241, Decimal('2111.4194'))
# (209, 'Pleasant Canned Tuna in Water', 1279, Decimal('2111.0720'))
# (210, 'Ebony Green Pepper', 801, Decimal('2109.6385'))
# (211, 'Gauss Monthly Auto Magazine', 1416, Decimal('2109.1304'))
# (212, 'Best Choice Chocolate Chip Cookies', 222, Decimal('2107.7990'))
# (213, 'Fabulous Apple Juice', 948, Decimal('2107.7864'))
# (214, 'Big Time Orange Popsicles', 394, Decimal('2107.0847'))
# (215, 'Red Wing Paper Plates', 450, Decimal('2102.8800'))
# (216, 'Monarch Manicotti', 884, Decimal('2102.0480'))
# (217, 'American Sliced Turkey', 1011, Decimal('2101.9002'))
# (218, 'Hermanos Fresh Lima Beans', 1440, Decimal('2099.9411'))
# (219, 'Fast Dried Dates', 559, Decimal('2097.5598'))
# (220, 'Blue Label Canned Beets', 16, Decimal('2093.5163'))
# (221, 'Red Wing Screw Driver', 474, Decimal('2089.7536'))
# (222, 'Bird Call Conditioning Shampoo', 1056, Decimal('2089.6760'))
# (223, 'Blue Medal Large Eggs', 80, Decimal('2088.9561'))
# (224, 'Cutting Edge Corned Beef', 694, Decimal('2087.9510'))
# (225, 'Fabulous Mango Drink', 940, Decimal('2087.6840'))
# (226, 'Musial White Chocolate Bar', 1198, Decimal('2087.1893'))
# (227, 'Modell Bagels', 1529, Decimal('2086.1619'))
# (228, 'Carrington Ice Cream', 1352, Decimal('2083.6155'))
# (229, 'BBB Best French Roast Coffee', 915, Decimal('2083.1895'))
# (230, 'Golden Low Fat French Fries', 86, Decimal('2080.6335'))
# (231, 'Hermanos Elephant Garlic', 1431, Decimal('2080.0038'))
# (232, 'Club Havarti Cheese', 50, Decimal('2078.6480'))
# (233, 'Fort West Lemon Cookies', 1475, Decimal('2078.4348'))
# (234, 'Cormorant Plastic Forks', 755, Decimal('2078.4308'))
# (235, 'Fantastic Pumpernickel Bread', 901, Decimal('2078.0201'))
# (236, 'Horatio Salted Pretzels', 1172, Decimal('2077.6662'))
# (237, 'CDR Corn Oil', 1541, Decimal('2076.1510'))
# (238, 'Best Choice Salsa Dip', 232, Decimal('2073.1501'))
# (239, 'Booker Low Fat Cottage Cheese', 1292, Decimal('2072.8584'))
# (240, 'Ebony Oranges', 834, Decimal('2071.1120'))
# (241, 'Denny C-Size Batteries', 136, Decimal('2067.0831'))
# (242, 'Better Canned Tuna in Water', 341, Decimal('2066.8078'))
# (243, 'Tell Tale Shitake Mushrooms', 491, Decimal('2065.8105'))
# (244, 'BBB Best Vegetable Oil', 918, Decimal('2064.5064'))
# (245, 'Fast Low Fat Chips', 551, Decimal('2064.1905'))
# (246, 'Carrington Low Fat Waffles', 1331, Decimal('2060.3156'))
# (247, 'Special Oatmeal', 950, Decimal('2059.9308'))
# (248, 'Super Grape Preserves', 295, Decimal('2059.0752'))
# (249, 'American Roasted Chicken', 1009, Decimal('2058.2100'))
# (250, 'Carrington Frozen Sausage Pizza', 1336, Decimal('2057.7639'))
# (251, 'Plato Low Fat Apple Butter', 1237, Decimal('2057.6875'))
# (252, 'Red Wing Plastic Spoons', 445, Decimal('2055.8974'))
# (253, 'Sunset Soft Napkins', 1398, Decimal('2054.4930'))
# (254, 'High Top Limes', 193, Decimal('2049.8336'))
# (255, 'Gorilla Havarti Cheese', 672, Decimal('2049.3238'))
# (256, 'PigTail Frozen Corn', 1045, Decimal('2045.0640'))
# (257, 'Best Choice Low Fat Popcorn', 231, Decimal('2042.5670'))
# (258, 'Sunset Copper Pot Scrubber', 1408, Decimal('2040.9240'))
# (259, 'BBB Best Strawberry Jam', 933, Decimal('2039.7286'))
# (260, 'Carrington Apple Cinnamon Waffles', 1343, Decimal('2038.0444'))
# (261, 'Horatio Raspberry Fruit Roll', 1184, Decimal('2035.5700'))
# (262, 'Tri-State Shitake Mushrooms', 1118, Decimal('2033.8302'))
# (263, 'Fast Avocado Dip', 544, Decimal('2029.4525'))
# (264, 'Big Time Turkey TV Dinner', 407, Decimal('2026.4730'))
# (265, 'Fast Apple Fruit Roll', 555, Decimal('2024.2368'))
# (266, 'Gorilla Cheese Spread', 674, Decimal('2019.6498'))
# (267, 'Pleasant Large Canned Shrimp', 1281, Decimal('2016.9478'))
# (268, 'Fast Fudge Cookies', 534, Decimal('2015.2574'))
# (269, 'Even Better 1% Milk', 997, Decimal('2014.2038'))
# (270, 'Red Wing Room Freshener', 465, Decimal('2014.0535'))
# (271, 'Booker Havarti Cheese', 1299, Decimal('2012.8956'))
# (272, 'Red Spade Foot-Long Hot Dogs', 68, Decimal('2012.7884'))
# (273, 'Ebony Fuji Apples', 832, Decimal('2011.1652'))
# (274, 'Booker 1% Milk', 1308, Decimal('2010.6714'))
# (275, 'Tri-State Green Pepper', 1117, Decimal('2010.5904'))
# (276, 'Hermanos Plums', 1450, Decimal('2009.3580'))
# (277, 'Fort West Dried Dates', 1497, Decimal('2008.7424'))
# (278, 'Even Better String Cheese', 986, Decimal('2007.8800'))
# (279, 'Pleasant Canned Yams', 1269, Decimal('2007.5496'))
# (280, 'Excellent Apple Drink', 322, Decimal('2002.9772'))
# (281, 'Nationeel Chocolate Chip Cookies', 844, Decimal('1998.2801'))
# (282, 'Carrington Grape Popsicles', 1349, Decimal('1998.1870'))
# (283, 'Tri-State Dried Mushrooms', 1128, Decimal('1995.8148'))
# (284, 'Red Wing 25 Watt Lightbulb', 456, Decimal('1994.3832'))
# (285, 'Tri-State Beets', 1114, Decimal('1988.8668'))
# (286, 'Walrus Chardonnay', 582, Decimal('1982.8020'))
# (287, 'Gorilla Low Fat String Cheese', 671, Decimal('1981.8520'))
# (288, 'Faux Products Apricot Shampoo', 121, Decimal('1977.9452'))
# (289, 'Best Choice Frosted Donuts', 252, Decimal('1975.5900'))
# (290, 'High Quality AAA-Size Batteries', 1076, Decimal('1973.6460'))
# (291, 'Imagine Ice Cream Sandwich', 726, Decimal('1973.6364'))
# (292, 'Bravo Creamed Corn', 639, Decimal('1972.6576'))
# (293, 'Booker Whole Milk', 1309, Decimal('1964.5534'))
# (294, 'Denny Toilet Paper', 151, Decimal('1961.0781'))
# (295, 'Gulf Coast Mint Chocolate Bar', 1503, Decimal('1960.8918'))
# (296, 'Carlson Sour Cream', 356, Decimal('1960.4284'))
# (297, 'Hilltop Deodorant', 1366, Decimal('1959.9036'))
# (298, 'Hermanos Mandarin Oranges', 1453, Decimal('1958.1182'))
# (299, 'Horatio Low Fat Popcorn', 1169, Decimal('1957.5024'))
# (300, 'High Quality Frying Pan', 1093, Decimal('1955.8443'))
# (301, 'Great Blueberry Muffins', 281, Decimal('1955.0105'))
# (302, 'Carrington Frozen Cheese Pizza', 1341, Decimal('1953.8730'))
# (303, 'Washington Cream Soda', 4, Decimal('1953.2240'))
# (304, 'Bravo Fancy Canned Sardines', 658, Decimal('1952.9160'))
# (305, 'Portsmouth Light Wine', 1205, Decimal('1951.8200'))
# (306, 'Fort West Raspberry Fruit Roll', 1495, Decimal('1949.7744'))
# (307, 'Super Pepper', 298, Decimal('1946.7004'))
# (308, 'Musial Semi-Sweet Chocolate Bar', 1194, Decimal('1946.5994'))
# (309, 'Best Choice Sesame Crackers', 241, Decimal('1946.1207'))
# (310, 'Imagine Lime Popsicles', 724, Decimal('1946.0448'))
# (311, 'High Quality Paper Plates', 1077, Decimal('1943.2240'))
# (312, 'Moms Potato Salad', 386, Decimal('1939.9439'))
# (313, 'Imagine Frozen Chicken Breast', 706, Decimal('1939.8836'))
# (314, 'Sunset AA-Size Batteries', 1395, Decimal('1939.0350'))
# (315, 'Moms Beef Bologna', 376, Decimal('1937.4904'))
# (316, 'Super French Roast Coffee', 288, Decimal('1935.2190'))
# (317, 'Faux Products Deodorant', 117, Decimal('1932.9200'))
# (318, 'Nationeel Low Fat BBQ Chips', 842, Decimal('1932.0960'))
# (319, 'Ebony Baby Onion', 811, Decimal('1930.4703'))
# (320, 'Denny AAA-Size Batteries', 138, Decimal('1929.7710'))
# (321, 'Carrington Frozen Peas', 1357, Decimal('1929.7097'))
# (322, 'Washington Apple Drink', 11, Decimal('1927.7973'))
# (323, 'Big Time Frozen Broccoli', 417, Decimal('1925.7328'))
# (324, 'Golden Frozen Broccoli', 106, Decimal('1924.9472'))
# (325, 'Landslide Brown Sugar', 597, Decimal('1923.2080'))
# (326, 'Cormorant 60 Watt Lightbulb', 754, Decimal('1921.9488'))
# (327, 'Walrus Merlot Wine', 581, Decimal('1920.8908'))
# (328, 'Nationeel Sesame Crackers', 863, Decimal('1920.3716'))
# (329, 'Cormorant Silver Cleaner', 780, Decimal('1919.6696'))
# (330, 'Club Low Fat String Cheese', 49, Decimal('1919.1978'))
# (331, 'Bravo Fancy Canned Anchovies', 655, Decimal('1916.6301'))
# (332, 'Shady Lake Manicotti', 573, Decimal('1913.1465'))
# (333, 'Musial Spicy Mints', 1196, Decimal('1910.7604'))
# (334, 'Moms Sliced Chicken', 387, Decimal('1908.9610'))
# (335, 'Hermanos Corn on the Cob', 1421, Decimal('1904.9868'))
# (336, 'High Top Mushrooms', 188, Decimal('1904.2206'))
# (337, 'Super Apple Jelly', 303, Decimal('1903.8078'))
# (338, 'Tell Tale Party Nuts', 525, Decimal('1901.5485'))
# (339, 'Bravo Canned Beets', 638, Decimal('1900.4895'))
# (340, 'Tell Tale Asparagus', 484, Decimal('1899.7160'))
# (341, 'High Top Summer Squash', 171, Decimal('1898.0890'))
# (342, 'Great Muffins', 279, Decimal('1896.9294'))
# (343, 'Special Wheat Puffs', 952, Decimal('1895.3412'))
# (344, 'Denny Tissues', 152, Decimal('1895.1753'))
# (345, 'Landslide Apple Jelly', 614, Decimal('1895.1030'))
# (346, 'Pleasant Noodle Soup', 1272, Decimal('1894.0504'))
# (347, 'Fantastic Rye Bread', 903, Decimal('1890.7308'))
# (348, 'Bravo Rice Soup', 659, Decimal('1889.1813'))
# (349, 'Bravo Canned Tuna in Oil', 653, Decimal('1888.2316'))
# (350, 'Tri-State Mandarin Oranges', 1142, Decimal('1887.8230'))
# (351, 'Fast Cheese Dip', 546, Decimal('1887.5922'))
# (352, 'Pearl Chablis Wine', 896, Decimal('1885.1388'))
# (353, 'Landslide Apple Butter', 612, Decimal('1879.7478'))
# (354, 'American Turkey Hot Dogs', 1005, Decimal('1879.4482'))
# (355, 'Gorilla Large Curd Cottage Cheese', 677, Decimal('1879.3632'))
# (356, 'Robust Monthly Fashion Magazine', 170, Decimal('1877.0880'))
# (357, 'Lake Sliced Ham', 1323, Decimal('1876.1022'))
# (358, 'Fast Chocolate Chip Cookies', 533, Decimal('1875.7904'))
# (359, 'Fast Strawberry Fruit Roll', 556, Decimal('1875.7050'))
# (360, 'Portsmouth Merlot Wine', 1208, Decimal('1873.7943'))
# (361, 'Denny Bees Wax Candles', 157, Decimal('1870.2705'))
# (362, 'Big Time Ice Cream Sandwich', 415, Decimal('1869.6459'))
# (363, 'Sunset Paper Cups', 1389, Decimal('1866.0376'))
# (364, 'Bird Call Childrens Aspirin', 1060, Decimal('1865.0982'))
# (365, 'Pleasant Chicken Ramen Soup', 1278, Decimal('1864.9788'))
# (366, 'Jumbo Egg Substitute', 703, Decimal('1864.4175'))
# (367, 'Club Mild Cheddar Cheese', 54, Decimal('1860.9309'))
# (368, 'Pleasant Canned Peas', 1277, Decimal('1860.5246'))
# (369, 'Denny Large Sponge', 162, Decimal('1857.2025'))
# (370, 'Modell Cranberry Muffins', 1527, Decimal('1857.1896'))
# (371, 'High Top Green Pepper', 179, Decimal('1855.5075'))
# (372, 'Pleasant Regular Ramen Soup', 1273, Decimal('1853.7324'))
# (373, 'Tell Tale Baby Onion', 500, Decimal('1853.2486'))
# (374, 'Hilltop Multi-Symptom Cold Remedy', 1377, Decimal('1850.3672'))
# (375, 'Mighty Good Monthly Sports Magazine', 1104, Decimal('1849.3825'))
# (376, 'Tri-State Oranges', 1150, Decimal('1849.2111'))
# (377, 'Cutting Edge Low Fat Cole Slaw', 691, Decimal('1847.3985'))
# (378, 'Best Choice Raspberry Fruit Roll', 246, Decimal('1845.3648'))
# (379, 'National Egg Substitute', 1019, Decimal('1842.0622'))
# (380, 'Amigo Scallops', 1465, Decimal('1841.9859'))
# (381, 'Johnson Grits', 1264, Decimal('1840.0735'))
# (382, 'Imagine Grape Popsicles', 722, Decimal('1839.1321'))
# (383, 'CDR Creamy Peanut Butter', 1556, Decimal('1836.8210'))
# (384, 'Best Choice Apple Fruit Roll', 244, Decimal('1836.4050'))
# (385, 'Ebony Golden Delcious Apples', 819, Decimal('1835.4574'))
# (386, 'Tell Tale Canned Peanuts', 517, Decimal('1834.6060'))
# (387, 'Tri-State Cantelope', 1146, Decimal('1833.5151'))
# (388, 'BBB Best Strawberry Preserves', 935, Decimal('1830.9760'))
# (389, 'BBB Best Extra Chunky Peanut Butter', 936, Decimal('1830.9636'))
# (390, 'Just Right Fancy Canned Anchovies', 971, Decimal('1828.5885'))
# (391, 'Dollar Monthly Fashion Magazine', 481, Decimal('1827.9045'))
# (392, 'Gulf Coast Semi-Sweet Chocolate Bar', 1505, Decimal('1827.7325'))
# (393, 'Nationeel Avocado Dip', 855, Decimal('1827.7199'))
# (394, 'Token Mango Drink', 624, Decimal('1826.5254'))
# (395, 'Red Spade Low Fat Cole Slaw', 69, Decimal('1823.7300'))
# (396, 'High Quality Room Freshener', 1092, Decimal('1822.2470'))
# (397, 'BBB Best Decaf Coffee', 916, Decimal('1819.9198'))
# (398, 'Ebony Shitake Mushrooms', 802, Decimal('1819.7439'))
# (399, 'Ship Shape Extra Lean Hamburger', 164, Decimal('1819.1844'))
# (400, 'Skinner Strawberry Drink', 1252, Decimal('1813.3980'))
# (401, 'Tri-State Baby Onion', 1127, Decimal('1811.5728'))
# (402, 'Hermanos Red Delcious Apples', 1447, Decimal('1811.1944'))
# (403, 'Bravo Beef Soup', 649, Decimal('1809.9135'))
# (404, 'Tri-State Fresh Lima Beans', 1129, Decimal('1809.8154'))
# (405, 'High Quality Counter Cleaner', 1081, Decimal('1808.5359'))
# (406, 'Discover Rice Medly', 892, Decimal('1808.2701'))
# (407, 'Tri-State Peaches', 1140, Decimal('1807.7440'))
# (408, 'High Top Firm Tofu', 194, Decimal('1805.5632'))
# (409, 'High Quality Scented Tissue', 1088, Decimal('1804.8848'))
# (410, 'Bravo Chicken Noodle Soup', 647, Decimal('1802.5912'))
# (411, 'Sunset Plastic Spoons', 1383, Decimal('1801.9666'))
# (412, 'Fabulous Cream Soda', 942, Decimal('1798.7112'))
# (413, 'Ebony Red Pepper', 805, Decimal('1796.8896'))
# (414, 'Hermanos Cauliflower', 1435, Decimal('1796.2064'))
# (415, 'Applause Canned Mixed Fruit', 660, Decimal('1795.9480'))
# (416, 'Moms Corned Beef', 383, Decimal('1792.9175'))
# (417, 'American Corned Beef', 1010, Decimal('1792.0625'))
# (418, 'Cutting Edge Sliced Turkey', 695, Decimal('1791.7152'))
# (419, 'Tell Tale Tomatos', 498, Decimal('1788.6465'))
# (420, 'Red Wing Toilet Bowl Cleaner', 453, Decimal('1786.8064'))
# (421, 'Even Better Low Fat Sour Cream', 982, Decimal('1786.2336'))
# (422, 'Moms Pimento Loaf', 375, Decimal('1786.0626'))
# (423, 'Special Grits', 953, Decimal('1785.1922'))
# (424, 'Best Choice Mini Donuts', 237, Decimal('1784.2904'))
# (425, 'Discover Spaghetti', 890, Decimal('1783.7784'))
# (426, 'Monarch Thai Rice', 886, Decimal('1782.4032'))
# (427, 'Nationeel Low Fat Chips', 862, Decimal('1782.0075'))
# (428, 'Better Canned Yams', 331, Decimal('1779.5889'))
# (429, 'Hermanos Oranges', 1461, Decimal('1779.0208'))
# (430, 'Carrington Frozen Pepperoni Pizza', 1340, Decimal('1778.8255'))
# (431, 'Medalist Thai Rice', 264, Decimal('1778.5606'))
# (432, 'Horatio Sesame Crackers', 1179, Decimal('1775.8549'))
# (433, 'Landslide Grape Preserves', 606, Decimal('1775.4205'))
# (434, 'Tri-State Party Nuts', 1152, Decimal('1773.6194'))
# (435, 'Even Better Low Fat String Cheese', 987, Decimal('1772.5183'))
# (436, 'American Pimento Loaf', 1002, Decimal('1770.4296'))
# (437, 'Blue Label Large Canned Shrimp', 32, Decimal('1765.5924'))
# (438, 'Bird Call 200 MG Ibuprofen', 1062, Decimal('1763.2944'))
# (439, 'Ebony Garlic', 806, Decimal('1763.2680'))
# (440, 'Hilltop Buffered Aspirin', 1372, Decimal('1761.7497'))
# (441, 'Thresher White Chocolate Bar', 882, Decimal('1760.6790'))
# (442, 'Tri-State Lettuce', 1119, Decimal('1760.5229'))
# (443, 'Even Better Cheese Spread', 990, Decimal('1760.3664'))
# (444, 'Club Large Curd Cottage Cheese', 55, Decimal('1760.1850'))
# (445, 'Pleasant Fancy Canned Oysters', 1284, Decimal('1759.4658'))
# (446, 'Plato Decaf Coffee', 1227, Decimal('1759.3972'))
# (447, 'Nationeel Sugar Cookies', 843, Decimal('1757.8848'))
# (448, 'Booker Buttermilk', 1306, Decimal('1757.8249'))
# (449, 'Applause Canned Peaches', 661, Decimal('1757.2464'))
# (450, 'Urban Small Brown Eggs', 388, Decimal('1756.1550'))
# (451, 'Hermanos Shitake Mushrooms', 1429, Decimal('1754.4960'))
# (452, 'Golden Pancake Mix', 99, Decimal('1753.8340'))
# (453, 'Best Choice BBQ Potato Chips', 218, Decimal('1752.2672'))
# (454, 'Big Time Chicken TV Dinner', 408, Decimal('1749.7260'))
# (455, 'Carlson Chocolate Milk', 369, Decimal('1748.7820'))
# (456, 'Bird Call Multi-Symptom Cold Remedy', 1066, Decimal('1746.4270'))
# (457, 'Shady Lake Thai Rice', 575, Decimal('1746.2745'))
# (458, 'Tell Tale Honey Dew', 520, Decimal('1744.6520'))
# (459, 'Red Wing 75 Watt Lightbulb', 452, Decimal('1743.7128'))
# (460, 'Denny Scented Toilet Tissue', 153, Decimal('1742.3504'))
# (461, 'Swell Canned Mixed Fruit', 349, Decimal('1738.1286'))
# (462, 'High Quality C-Size Batteries', 1074, Decimal('1738.1203'))
# (463, 'Landslide Canola Oil', 605, Decimal('1737.4556'))
# (464, 'Hermanos Cantelope', 1457, Decimal('1737.2342'))
# (465, 'Fast Fondue Mix', 547, Decimal('1736.8428'))
# (466, 'Ebony Broccoli', 825, Decimal('1736.5163'))
# (467, 'Red Wing AA-Size Batteries', 457, Decimal('1736.3580'))
# (468, 'Fort West Buttered Popcorn', 1478, Decimal('1736.2352'))
# (469, 'CDR Hot Chocolate', 1534, Decimal('1733.4968'))
# (470, 'Better Fancy Canned Clams', 345, Decimal('1730.1789'))
# (471, 'Walrus Imported Beer', 577, Decimal('1729.5668'))
# (472, 'CDR Apple Jelly', 1552, Decimal('1726.7850'))
# (473, 'CDR Brown Sugar', 1535, Decimal('1725.8952'))
# (474, 'Horatio Avocado Dip', 1171, Decimal('1725.6270'))
# (475, 'Best Choice Chocolate Donuts', 239, Decimal('1725.5901'))
# (476, 'Skinner Apple Juice', 1259, Decimal('1723.7058'))
# (477, 'PigTail Frozen Cheese Pizza', 1030, Decimal('1723.4184'))
# (478, 'Cutting Edge Low Fat Bologna', 688, Decimal('1720.8096'))
# (479, 'American Low Fat Bologna', 1004, Decimal('1720.4215'))
# (480, 'Big Time Ice Cream', 414, Decimal('1718.7296'))
# (481, 'Landslide Strawberry Preserves', 619, Decimal('1717.8075'))
# (482, 'Denny Plastic Spoons', 134, Decimal('1716.9408'))
# (483, 'Carrington Low Fat French Fries', 1335, Decimal('1713.2690'))
# (484, 'Tell Tale Beets', 487, Decimal('1713.2440'))
# (485, 'Just Right Large Canned Shrimp', 970, Decimal('1711.4952'))
# (486, 'Good Light Beer', 273, Decimal('1711.3436'))
# (487, 'Carrington Frozen Chicken Wings', 1360, Decimal('1709.8994'))
# (488, 'Blue Medal Small Brown Eggs', 77, Decimal('1704.1360'))
# (489, 'American Sliced Ham', 1012, Decimal('1704.0240'))
# (490, 'Nationeel Salted Pretzels', 856, Decimal('1703.2813'))
# (491, 'Cormorant Scissors', 783, Decimal('1702.7686'))
# (492, 'Cormorant 75 Watt Lightbulb', 763, Decimal('1702.3035'))
# (493, 'Nationeel Chocolate Donuts', 861, Decimal('1701.1820'))
# (494, 'Blue Label Beef Soup', 27, Decimal('1700.1075'))
# (495, 'Nationeel Buttered Popcorn', 851, Decimal('1699.4457'))
# (496, 'Sunset D-Size Batteries', 1396, Decimal('1699.0740'))
# (497, 'Blue Label Creamed Corn', 17, Decimal('1697.8416'))
# (498, 'Radius Wheat Puffs', 636, Decimal('1696.3848'))
# (499, 'Mighty Good Monthly Home Magazine', 1107, Decimal('1696.2480'))
# (500, 'Blue Label Canned Yams', 20, Decimal('1694.0486'))
# (501, 'Ebony Prepared Salad', 799, Decimal('1691.5324'))
# (502, 'High Top Walnuts', 211, Decimal('1691.2960'))
# (503, 'Landslide Low Fat Apple Butter', 610, Decimal('1689.1751'))
# (504, 'Ebony Walnuts', 833, Decimal('1689.1564'))
# (505, 'Monarch Ravioli', 883, Decimal('1687.2780'))
# (506, 'Best Choice Salted Pretzels', 234, Decimal('1686.8790'))
# (507, 'Consolidated Childrens Cold Remedy', 751, Decimal('1685.8401'))
# (508, 'Super Sesame Oil', 283, Decimal('1684.5738'))
# (509, 'Green Ribbon Canned Peaches', 39, Decimal('1682.4789'))
# (510, 'Red Spade Corned Beef', 72, Decimal('1681.6750'))
# (511, 'Ebony Summer Squash', 793, Decimal('1680.0465'))
# (512, 'Gulf Coast White Chocolate Bar', 1509, Decimal('1678.4552'))
# (513, 'Horatio Cheese Dip', 1173, Decimal('1676.4825'))
# (514, 'Discover Thai Rice', 891, Decimal('1675.3022'))
# (515, 'BBB Best White Sugar', 914, Decimal('1672.8492'))
# (516, 'Sunset Plastic Knives', 1384, Decimal('1672.3247'))
# (517, 'Fast Mini Donuts', 548, Decimal('1670.5450'))
# (518, 'High Quality Silver Cleaner', 1096, Decimal('1669.7088'))
# (519, 'Big Time Lime Popsicles', 413, Decimal('1668.9825'))
# (520, 'Hilltop Apricot Shampoo', 1370, Decimal('1668.3562'))
# (521, 'Musial Tasty Candy Bar', 1191, Decimal('1668.0720'))
# (522, 'High Top Golden Delcious Apples', 197, Decimal('1667.5755'))
# (523, 'Shady Lake Ravioli', 572, Decimal('1666.6400'))
# (524, 'Best Grits', 326, Decimal('1665.2740'))
# (525, 'Better Fancy Canned Anchovies', 344, Decimal('1663.3284'))
# (526, 'Quick Extra Lean Hamburger', 475, Decimal('1662.8310'))
# (527, 'Just Right Chicken Noodle Soup', 963, Decimal('1662.4560'))
# (528, 'Red Wing C-Size Batteries', 447, Decimal('1662.3936'))
# (529, 'Gorilla Head Cheese', 673, Decimal('1660.4674'))
# (530, 'Lake Roasted Chicken', 1320, Decimal('1659.7868'))
# (531, 'Sunset Frying Pan', 1404, Decimal('1659.6853'))
# (532, 'Plato Chunky Peanut Butter', 1222, Decimal('1658.8950'))
# (533, 'High Top Party Nuts', 214, Decimal('1658.1882'))
# (534, 'Tell Tale Plums', 512, Decimal('1657.9466'))
# (535, 'Tell Tale Elephant Garlic', 493, Decimal('1657.7088'))
# (536, 'Steady Apricot Shampoo', 432, Decimal('1657.4550'))
# (537, 'High Quality D-Size Batteries', 1085, Decimal('1657.2640'))
# (538, 'Fabulous Apple Drink', 949, Decimal('1656.8259'))
# (539, 'Gulf Coast Tasty Candy Bar', 1502, Decimal('1656.4669'))
# (540, 'CDR Strawberry Jam', 1555, Decimal('1654.4190'))
# (541, 'Framton City Map', 1291, Decimal('1652.7570'))
# (542, 'Golden Lime Popsicles', 102, Decimal('1651.3245'))
# (543, 'Portsmouth Imported Beer', 1204, Decimal('1650.3480'))
# (544, 'Club Muenster Cheese', 47, Decimal('1647.2672'))
# (545, 'Colossal Ravioli', 1199, Decimal('1644.1088'))
# (546, 'Red Wing Scented Toilet Tissue', 464, Decimal('1642.7976'))
# (547, 'Landslide Columbian Coffee', 607, Decimal('1642.5908'))
# (548, 'Dollar Monthly Auto Magazine', 478, Decimal('1639.4649'))
# (549, 'Better Vegetable Soup', 332, Decimal('1634.3392'))
# (550, 'Excellent Diet Cola', 318, Decimal('1634.2755'))
# (551, 'Fast Lemon Cookies', 537, Decimal('1631.6580'))
# (552, 'Hermanos Broccoli', 1452, Decimal('1631.5495'))
# (553, 'Nationeel Grape Fruit Roll', 869, Decimal('1630.0680'))
# (554, 'Ebony Beets', 798, Decimal('1628.2493'))
# (555, 'High Quality Plastic Forks', 1071, Decimal('1628.2200'))
# (556, 'Portsmouth Chardonnay', 1209, Decimal('1624.6980'))
# (557, 'Horatio Salsa Dip', 1170, Decimal('1622.9925'))
# (558, 'Cormorant Plastic Spoons', 756, Decimal('1620.4620'))
# (559, 'Cormorant AA-Size Batteries', 768, Decimal('1620.1752'))
# (560, 'Sunset 25 Watt Lightbulb', 1394, Decimal('1620.0855'))
# (561, 'Denny Screw Driver', 163, Decimal('1619.6852'))
# (562, 'Nationeel Lemon Cookies', 848, Decimal('1618.3860'))
# (563, 'Red Wing Scented Tissue', 461, Decimal('1618.2368'))
# (564, 'Sunset Room Freshener', 1403, Decimal('1615.6948'))
# (565, 'Excellent Apple Juice', 321, Decimal('1612.8925'))
# (566, 'Landslide Decaf Coffee', 600, Decimal('1612.7727'))
# (567, 'Robust Monthly Sports Magazine', 166, Decimal('1612.5395'))
# (568, 'Choice Semi-Sweet Chocolate Bar', 256, Decimal('1610.9880'))
# (569, 'High Top Mixed Nuts', 205, Decimal('1610.8240'))
# (570, 'Hilltop Tartar Control Toothpaste', 1363, Decimal('1610.3640'))
# (571, 'Gorilla Sour Cream', 667, Decimal('1609.4330'))
# (572, 'Club Low Fat Sour Cream', 44, Decimal('1608.7458'))
# (573, 'Tri-State Limes', 1131, Decimal('1608.5280'))
# (574, 'Consolidated Angled Toothbrush', 742, Decimal('1607.8465'))
# (575, 'Pleasant Vegetable Soup', 1270, Decimal('1601.3032'))
# (576, 'High Top Fresh Lima Beans', 191, Decimal('1600.0537'))
# (577, 'Fort West Cheese Crackers', 1477, Decimal('1597.9140'))
# (578, 'Bird Call Angled Toothbrush', 1058, Decimal('1596.9912'))
# (579, 'Token Orange Juice', 630, Decimal('1596.3920'))
# (580, 'BBB Best Grape Preserves', 922, Decimal('1596.1911'))
# (581, 'Fort West Frosted Donuts', 1501, Decimal('1595.0844'))
# (582, 'Pearl White Zinfandel Wine', 899, Decimal('1593.3888'))
# (583, 'Atomic Spicy Mints', 569, Decimal('1591.1548'))
# (584, 'Faux Products Mint Mouthwash', 131, Decimal('1584.4800'))
# (585, 'Hermanos Garlic', 1433, Decimal('1581.0771'))
# (586, 'Hilltop Childrens Aspirin', 1371, Decimal('1580.2566'))
# (587, 'High Quality Toilet Paper', 1089, Decimal('1579.0216'))
# (588, 'Good Chardonnay', 271, Decimal('1578.8466'))
# (589, 'Tell Tale Mushrooms', 499, Decimal('1575.1048'))
# (590, 'Best Choice Avocado Dip', 233, Decimal('1573.3176'))
# (591, 'Ebony Onions', 800, Decimal('1573.2760'))
# (592, 'Carrington Ice Cream Sandwich', 1353, Decimal('1571.5616'))
# (593, 'Cormorant Copper Cleaner', 778, Decimal('1570.9904'))
# (594, 'Tri-State Fancy Plums', 1138, Decimal('1567.1144'))
# (595, 'Just Right Chicken Soup', 957, Decimal('1563.8535'))
# (596, 'Just Right Fancy Canned Clams', 972, Decimal('1563.5422'))
# (597, 'Carlson Sharp Cheddar Cheese', 364, Decimal('1559.0960'))
# (598, 'Faux Products Laundry Detergent', 130, Decimal('1558.8146'))
# (599, 'Fort West Potato Chips', 1474, Decimal('1554.5790'))
# (600, 'Denny 25 Watt Lightbulb', 145, Decimal('1553.4745'))
# (601, 'Cutting Edge Sliced Chicken', 698, Decimal('1553.1314'))
# (602, 'Blue Label Canned String Beans', 18, Decimal('1551.3234'))
# (603, 'Carrington Chicken TV Dinner', 1346, Decimal('1549.0730'))
# (604, 'Bravo Large Canned Shrimp', 654, Decimal('1548.7073'))
# (605, 'Excel Monthly Home Magazine', 791, Decimal('1545.8930'))
# (606, 'Dollar Monthly Computer Magazine', 479, Decimal('1545.3555'))
# (607, 'PigTail Turkey TV Dinner', 1034, Decimal('1543.3476'))
# (608, 'Lake Corned Beef', 1321, Decimal('1542.2313'))
# (609, 'Big Time Popsicles', 420, Decimal('1541.2619'))
# (610, 'Landslide Vegetable Oil', 602, Decimal('1537.3118'))
# (611, 'Golden Frozen Chicken Thighs', 110, Decimal('1536.2420'))
# (612, 'Atomic Mints', 570, Decimal('1534.5288'))
# (613, 'Faux Products 200 MG Acetominifen', 125, Decimal('1532.1280'))
# (614, 'Curlew Scallops', 838, Decimal('1528.9854'))
# (615, 'Fort West Dried Apricots', 1500, Decimal('1527.0242'))
# (616, 'Fabulous Diet Soda', 943, Decimal('1524.6569'))
# (617, 'Horatio Cheese Crackers', 1166, Decimal('1524.6127'))
# (618, 'Imagine Chicken TV Dinner', 719, Decimal('1523.3365'))
# (619, 'Super Vegetable Oil', 291, Decimal('1522.5870'))
# (620, 'Landslide Pepper', 609, Decimal('1520.2005'))
# (621, 'CDR Apple Jam', 1554, Decimal('1518.6914'))
# (622, 'Bravo Turkey Noodle Soup', 648, Decimal('1517.6240'))
# (623, 'Nationeel Dried Apricots', 873, Decimal('1516.9485'))
# (624, 'Landslide French Roast Coffee', 599, Decimal('1516.7928'))
# (625, 'Cormorant Screw Driver', 785, Decimal('1514.2164'))
# (626, 'Colony Cranberry Muffins', 589, Decimal('1513.2825'))
# (627, 'Tri-State Prepared Salad', 1115, Decimal('1511.7000'))
# (628, 'Walrus Chablis Wine', 580, Decimal('1510.3711'))
# (629, 'Jeffers Grits', 15, Decimal('1510.1863'))
# (630, 'Walrus Light Beer', 584, Decimal('1508.7268'))
# (631, 'Ebony Elephant Garlic', 804, Decimal('1508.4576'))
# (632, 'Tell Tale Macintosh Apples', 507, Decimal('1508.4366'))
# (633, 'Radius Oatmeal', 634, Decimal('1507.4246'))
# (634, 'Hermanos Canned Peanuts', 1455, Decimal('1505.5524'))
# (635, 'Even Better Blueberry Yogurt', 1000, Decimal('1502.0422'))
# (636, 'High Top Macintosh Apples', 196, Decimal('1500.9943'))
# (637, 'Carlson Low Fat Cottage Cheese', 354, Decimal('1499.6475'))
# (638, 'Consolidated Dishwasher Detergent', 749, Decimal('1498.8579'))
# (639, 'Just Right Turkey Noodle Soup', 964, Decimal('1497.6740'))
# (640, 'Carrington Pancake Mix', 1348, Decimal('1496.0543'))
# (641, 'Tell Tale Prepared Salad', 488, Decimal('1495.2588'))
# (642, 'BBB Best Hot Chocolate', 912, Decimal('1495.0235'))
# (643, 'Tri-State Potatos', 1123, Decimal('1494.8528'))
# (644, 'Excellent Cola', 317, Decimal('1493.5834'))
# (645, 'Tri-State Fuji Apples', 1148, Decimal('1492.4658'))
# (646, 'Nationeel Fondue Mix', 858, Decimal('1491.4626'))
# (647, 'Golden Low Fat Waffles', 82, Decimal('1490.0220'))
# (648, 'Plato Creamy Peanut Butter', 1245, Decimal('1487.4216'))
# (649, 'Moms Low Fat Bologna', 377, Decimal('1486.6320'))
# (650, 'Tell Tale Corn on the Cob', 483, Decimal('1486.4086'))
# (651, 'Fort West Chocolate Donuts', 1488, Decimal('1485.2214'))
# (652, 'Sunset Scented Toilet Tissue', 1402, Decimal('1485.1319'))
# (653, 'Consolidated Mint Mouthwash', 753, Decimal('1483.9524'))
# (654, 'Fort West Grape Fruit Roll', 1496, Decimal('1483.9019'))
# (655, 'Horatio Chocolate Chip Cookies', 1160, Decimal('1483.5552'))
# (656, 'Monarch Rice Medly', 887, Decimal('1482.5700'))
# (657, 'Super Grape Jelly', 311, Decimal('1481.9090'))
# (658, 'Carrington Popsicles', 1358, Decimal('1480.9410'))
# (659, 'Red Spade Roasted Chicken', 71, Decimal('1478.8356'))
# (660, 'Better Fancy Canned Oysters', 346, Decimal('1477.6612'))
# (661, 'Kiwi Scallops', 527, Decimal('1477.0042'))
# (662, 'CDR Canola Oil', 1543, Decimal('1476.0960'))
# (663, 'Top Measure Chardonnay', 1520, Decimal('1468.0050'))
# (664, 'Hermanos Sweet Peas', 1423, Decimal('1465.2525'))
# (665, 'Jeffers Corn Puffs', 13, Decimal('1463.6745'))
# (666, 'Denny Counter Cleaner', 143, Decimal('1463.4786'))
# (667, 'Big Time Frozen Chicken Breast', 395, Decimal('1463.2686'))
# (668, 'Red Spade Chicken Hot Dogs', 63, Decimal('1462.7280'))
# (669, 'Horatio Fondue Mix', 1174, Decimal('1460.9720'))
# (670, 'Imagine Turkey TV Dinner', 718, Decimal('1458.5840'))
# (671, 'Hermanos Beets', 1425, Decimal('1458.5508'))
# (672, 'High Top Fancy Plums', 200, Decimal('1458.2685'))
# (673, 'Consolidated Deodorant', 739, Decimal('1457.9642'))
# (674, 'Fast Fudge Brownies', 535, Decimal('1454.4776'))
# (675, 'CDR Pepper', 1547, Decimal('1453.1566'))
# (676, 'Fort West Frosted Cookies', 1491, Decimal('1451.0436'))
# (677, 'Genteel Extra Lean Hamburger', 1102, Decimal('1450.9730'))
# (678, 'Faux Products Childrens Aspirin', 122, Decimal('1450.0931'))
# (679, 'Hermanos Firm Tofu', 1443, Decimal('1448.3014'))
# (680, 'American Low Fat Cole Slaw', 1007, Decimal('1447.4428'))
# (681, 'High Top Red Pepper', 183, Decimal('1446.0482'))
# (682, 'Fast Chocolate Donuts', 550, Decimal('1445.8800'))
# (683, 'Golden Frozen Peas', 108, Decimal('1442.3778'))
# (684, 'Steady HCL Nasal Spray', 437, Decimal('1439.2032'))
# (685, 'Best Choice Corn Chips', 219, Decimal('1438.9704'))
# (686, 'Urban Large Brown Eggs', 389, Decimal('1438.5335'))
# (687, 'Prelude Rosy Sunglasses', 662, Decimal('1436.6260'))
# (688, 'Better Large Canned Shrimp', 343, Decimal('1434.9700'))
# (689, 'Golden Frozen Chicken Breast', 84, Decimal('1433.7182'))
# (690, 'Lake Foot-Long Hot Dogs', 1317, Decimal('1432.2750'))
# (691, 'Ebony Sweet Onion', 829, Decimal('1431.2886'))
# (692, 'Red Wing Toilet Paper', 462, Decimal('1428.8800'))
# (693, 'Tri-State Golden Delcious Apples', 1135, Decimal('1428.1736'))
# (694, 'Blue Label Vegetable Soup', 21, Decimal('1427.2415'))
# (695, 'PigTail Fajita French Fries', 1027, Decimal('1426.8408'))
# (696, 'Gorilla Strawberry Yogurt', 683, Decimal('1426.5288'))
# (697, 'Bird Call Apricot Shampoo', 1059, Decimal('1426.4820'))
# (698, 'Fort West Raisins', 1498, Decimal('1426.3220'))
# (699, 'Sunset C-Size Batteries', 1385, Decimal('1426.1040'))
# (700, 'Blue Medal Large Brown Eggs', 78, Decimal('1425.6024'))
# (701, 'Booker Muenster Cheese', 1296, Decimal('1424.3246'))
# (702, 'Nationeel Fudge Brownies', 846, Decimal('1421.7282'))
# (703, 'Moms Cole Slaw', 381, Decimal('1420.8806'))
# (704, 'Horatio Buttered Popcorn', 1167, Decimal('1420.2225'))
# (705, 'Skinner Orange Juice', 1257, Decimal('1418.6444'))
# (706, 'Denny Toilet Bowl Cleaner', 142, Decimal('1415.2928'))
# (707, 'Red Spade Sliced Turkey', 73, Decimal('1415.2886'))
# (708, 'Ebony Cantelope', 830, Decimal('1415.1935'))
# (709, 'Good Merlot Wine', 270, Decimal('1414.7840'))
# (710, 'Denny 60 Watt Lightbulb', 132, Decimal('1413.5616'))
# (711, 'High Top Beets', 176, Decimal('1410.8277'))
# (712, 'Red Wing Frying Pan', 466, Decimal('1410.2060'))
# (713, 'Queen City Map', 42, Decimal('1409.5770'))
# (714, 'Hermanos Honey Dew', 1458, Decimal('1409.2840'))
# (715, 'Bravo Fancy Canned Oysters', 657, Decimal('1408.9308'))
# (716, 'Tell Tale Sweet Peas', 485, Decimal('1404.6003'))
# (717, 'Hilltop HCL Nasal Spray', 1375, Decimal('1403.9469'))
# (718, 'Carlson Large Curd Cottage Cheese', 366, Decimal('1403.8932'))
# (719, 'Excellent Berry Juice', 312, Decimal('1401.9873'))
# (720, 'Nationeel Corn Chips', 841, Decimal('1398.6740'))
# (721, 'Club Cheese Spread', 52, Decimal('1396.8073'))
# (722, 'Giant Small Eggs', 1328, Decimal('1396.7026'))
# (723, 'High Quality Screw Driver', 1101, Decimal('1395.4120'))
# (724, 'Gorilla 1% Milk', 681, Decimal('1394.8580'))
# (725, 'Modell Muffins', 1528, Decimal('1392.9716'))
# (726, 'Sphinx Wheat Bread', 1220, Decimal('1392.2415'))
# (727, 'Washington Diet Cola', 7, Decimal('1391.9652'))
# (728, 'Blue Label Canned Tomatos', 22, Decimal('1390.3048'))
# (729, 'PigTail Frozen Chicken Thighs', 1048, Decimal('1388.6093'))
# (730, 'Imagine Frozen Chicken Wings', 733, Decimal('1387.4835'))
# (731, 'Best Choice Low Fat BBQ Chips', 220, Decimal('1386.1545'))
# (732, 'Tell Tale Lettuce', 492, Decimal('1385.7507'))
# (733, 'Fort West Fudge Brownies', 1473, Decimal('1385.3672'))
# (734, 'PigTail Blueberry Waffles', 1026, Decimal('1384.8408'))
# (735, 'Super Grape Jam', 304, Decimal('1384.2360'))
# (736, 'Tell Tale Red Delcious Apples', 509, Decimal('1378.9630'))
# (737, 'Ebony New Potatos', 797, Decimal('1378.1889'))
# (738, 'Washington Cranberry Juice', 9, Decimal('1377.9964'))
# (739, 'Special Corn Puffs', 951, Decimal('1377.5761'))
# (740, 'Carlson Cheese Spread', 363, Decimal('1377.5034'))
# (741, 'Bravo Canned String Beans', 640, Decimal('1373.8137'))
# (742, 'PigTail Waffles', 1028, Decimal('1373.7920'))
# (743, 'Imagine Frozen Corn', 729, Decimal('1372.4912'))
# (744, 'Best Choice Frosted Cookies', 242, Decimal('1372.3115'))
# (745, 'Booker String Cheese', 1297, Decimal('1371.1600'))
# (746, 'Faux Products Extra Moisture Shampoo', 119, Decimal('1370.7816'))
# (747, 'Golden Frozen Pepperoni Pizza', 91, Decimal('1370.3644'))
# (748, 'Colossal Manicotti', 1200, Decimal('1365.3992'))
# (749, 'High Quality Tissues', 1090, Decimal('1364.9275'))
# (750, 'Faux Products Angled Toothbrush', 120, Decimal('1364.2716'))
# (751, 'Great Bagels', 280, Decimal('1364.1608'))
# (752, 'Best Choice Dried Apples', 243, Decimal('1363.8618'))
# (753, 'Tri-State Onions', 1116, Decimal('1363.3664'))
# (754, 'High Top Cantelope', 208, Decimal('1360.9947'))
# (755, 'Best Choice Beef Jerky', 238, Decimal('1359.8319'))
# (756, 'High Top Cauliflower', 186, Decimal('1359.4749'))
# (757, 'Blue Label Fancy Canned Oysters', 35, Decimal('1358.8627'))
# (758, 'High Quality Paper Towels', 1086, Decimal('1357.7245'))
# (759, 'Nationeel Dried Dates', 870, Decimal('1357.1133'))
# (760, 'Good Chardonnay Wine', 268, Decimal('1356.3719'))
# (761, 'Just Right Canned Tomatos', 960, Decimal('1355.6825'))
# (762, 'Pearl Light Beer', 900, Decimal('1355.6052'))
# (763, 'PigTail Beef TV Dinner', 1036, Decimal('1355.4974'))
# (764, 'Cormorant Economy Toilet Brush', 782, Decimal('1350.5310'))
# (765, 'Denny Soft Napkins', 149, Decimal('1349.3808'))
# (766, 'Booker Jack Cheese', 1295, Decimal('1348.8165'))
# (767, 'BBB Best Sesame Oil', 910, Decimal('1348.1312'))
# (768, 'Sunset Screw Driver', 1412, Decimal('1346.9166'))
# (769, 'Washington Orange Juice', 8, Decimal('1346.6964'))
# (770, 'Plato Regular Coffee', 1228, Decimal('1346.5215'))
# (771, 'Tri-State Almonds', 1133, Decimal('1344.9128'))
# (772, 'Fort West Fudge Cookies', 1472, Decimal('1343.0340'))
# (773, 'Cormorant Tissues', 774, Decimal('1342.7225'))
# (774, 'Sphinx Blueberry Muffins', 1219, Decimal('1342.5096'))
# (775, 'CDR Chunky Peanut Butter', 1533, Decimal('1341.9000'))
# (776, 'Moms Roasted Chicken', 382, Decimal('1340.1936'))
# (777, 'Carrington Fajita French Fries', 1338, Decimal('1339.9254'))
# (778, 'Consolidated Conditioning Shampoo', 740, Decimal('1339.1666'))
# (779, 'Fantastic Cranberry Muffins', 905, Decimal('1339.1442'))
# (780, 'CDR Columbian Coffee', 1545, Decimal('1339.0775'))
# (781, 'Akron Eyeglass Screwdriver', 663, Decimal('1338.6912'))
# (782, 'Shady Lake Spaghetti', 574, Decimal('1338.6045'))
# (783, 'Nationeel Strawberry Fruit Roll', 867, Decimal('1337.6200'))
# (784, 'Amigo Lox', 1464, Decimal('1336.9432'))
# (785, 'Sunset 75 Watt Lightbulb', 1390, Decimal('1336.4652'))
# (786, 'Fort West Sugar Cookies', 1470, Decimal('1336.2968'))
# (787, 'CDR Grape Jam', 1553, Decimal('1335.1638'))
# (788, 'Kiwi Lox', 526, Decimal('1334.4300'))
# (789, 'Sphinx Cranberry Muffins', 1216, Decimal('1328.3294'))
# (790, 'Ship Shape Seasoned Hamburger', 165, Decimal('1325.9225'))
# (791, 'Consolidated Multi-Symptom Cold Remedy', 750, Decimal('1325.3565'))
# (792, 'Tri-State Macintosh Apples', 1134, Decimal('1323.1582'))
# (793, 'Steady Mint Mouthwash', 442, Decimal('1322.8096'))
# (794, 'Denny Paper Cups', 140, Decimal('1322.5212'))
# (795, 'Best Choice Buttered Popcorn', 229, Decimal('1321.0966'))
# (796, 'Club Chocolate Milk', 58, Decimal('1320.3960'))
# (797, 'Excellent Orange Juice', 319, Decimal('1320.1920'))
# (798, 'CDR French Roast Coffee', 1537, Decimal('1319.6274'))
# (799, 'Nationeel Raisins', 871, Decimal('1317.8282'))
# (800, 'American Chicken Hot Dogs', 1001, Decimal('1317.4560'))
# (801, 'Atomic Semi-Sweet Chocolate Bar', 567, Decimal('1317.2690'))
# (802, 'Imagine Pancake Mix', 721, Decimal('1317.1958'))
# (803, 'Sunset Large Sponge', 1411, Decimal('1316.8900'))
# (804, 'Jumbo Large Brown Eggs', 700, Decimal('1316.2820'))
# ...
# (1291, 'Musial Mint Chocolate Bar', 1192, Decimal('719.5552'))
# (1292, 'Pleasant Creamed Corn', 1266, Decimal('717.6996'))
# (1293, 'Big Time Low Fat Waffles', 393, Decimal('716.3632'))
# (1294, 'Even Better Low Fat Cottage Cheese', 981, Decimal('716.3308'))
# (1295, 'Excellent Cream Soda', 315, Decimal('716.2560'))
# (1296, 'PigTail Ice Cream Sandwich', 1042, Decimal('715.1045'))
# (1297, 'National Large Brown Eggs', 1016, Decimal('714.8583'))
# (1298, 'Super Canola Oil', 294, Decimal('714.3576'))
# (1299, 'Carrington Frozen Chicken Thighs', 1359, Decimal('714.2524'))
# (1300, 'Plato Grape Jelly', 1249, Decimal('712.9900'))
# (1301, 'Even Better Buttermilk', 995, Decimal('711.6430'))
# (1302, 'Big Time Home Style French Fries', 412, Decimal('706.7256'))
# (1303, 'PigTail Frozen Broccoli', 1044, Decimal('701.3956'))
# (1304, 'Red Wing Counter Cleaner', 454, Decimal('698.5137'))
# (1305, 'Urban Large Eggs', 391, Decimal('697.9680'))
# (1306, 'High Top Tomatos', 187, Decimal('697.7652'))
# (1307, 'Hermanos Tomatos', 1436, Decimal('696.6792'))
# (1308, 'Fort West Corn Chips', 1468, Decimal('696.2634'))
# (1309, 'Washington Cola', 6, Decimal('695.5430'))
# (1310, 'Hermanos Potatos', 1434, Decimal('689.9298'))
# (1311, 'Super Strawberry Jelly', 297, Decimal('689.7510'))
# (1312, 'Lake Low Fat Cole Slaw', 1318, Decimal('689.4927'))
# (1313, 'PigTail Lime Popsicles', 1040, Decimal('682.5852'))
# (1314, 'Golden Ice Cream', 103, Decimal('682.0905'))
# (1315, 'Pearl Imported Beer', 893, Decimal('680.2341'))
# (1316, 'Best Choice Dried Dates', 248, Decimal('678.7464'))
# (1317, 'Great Wheat Bread', 282, Decimal('676.0263'))
# (1318, 'Modell White Bread', 1524, Decimal('672.9534'))
# (1319, 'American Cole Slaw', 1008, Decimal('671.1668'))
# (1320, 'Carlson 1% Milk', 370, Decimal('671.1032'))
# (1321, 'Jardon Ravioli', 1510, Decimal('667.9488'))
# (1322, 'PigTail Orange Popsicles', 1021, Decimal('659.0318'))
# (1323, 'Steady Angled Toothbrush', 431, Decimal('658.6176'))
# (1324, 'High Top Onions', 178, Decimal('657.3525'))
# (1325, 'Red Spade Cole Slaw', 70, Decimal('654.1389'))
# (1326, 'Pleasant Turkey Noodle Soup', 1275, Decimal('652.4739'))
# (1327, 'Tri-State Walnuts', 1149, Decimal('651.8424'))
# (1328, 'Carrington Frozen Chicken Breast', 1333, Decimal('651.2976'))
# (1329, 'Fort West Beef Jerky', 1487, Decimal('648.0710'))
# (1330, 'Even Better Chocolate Milk', 996, Decimal('645.3115'))
# (1331, 'Cormorant Scented Toilet Tissue', 775, Decimal('643.6155'))
# (1332, 'Super Apple Preserves', 310, Decimal('641.5540'))
# (1333, 'PigTail Lemon Popsicles', 1050, Decimal('640.2560'))
# (1334, 'Golden Frozen Mushroom Pizza', 93, Decimal('637.9392'))
# (1335, 'CDR Oregano', 1551, Decimal('636.5964'))
# (1336, 'Colony Bagels', 591, Decimal('632.3733'))
# (1337, 'Cutting Edge Beef Bologna', 687, Decimal('631.8580'))
# (1338, 'Consolidated Buffered Aspirin', 745, Decimal('631.2950'))
# (1339, 'Top Measure Imported Beer', 1515, Decimal('629.7830'))
# (1340, 'Landslide Tomato Sauce', 604, Decimal('628.0500'))
# (1341, 'Sunset Toilet Paper', 1400, Decimal('622.2616'))
# (1342, 'Token Cranberry Juice', 631, Decimal('622.2216'))
# (1343, 'Tell Tale Garlic', 495, Decimal('621.2817'))
# (1344, 'Dollar Monthly Sports Magazine', 477, Decimal('620.0170'))
# (1345, 'Red Wing Economy Toilet Brush', 471, Decimal('609.8757'))
# (1346, 'Fast Graham Crackers', 538, Decimal('608.9547'))
# (1347, 'Ebony Asparagus', 795, Decimal('605.9616'))
# (1348, 'Big Time Blueberry Waffles', 399, Decimal('604.5804'))
# (1349, 'High Top Red Delcious Apples', 198, Decimal('601.5696'))
# (1350, 'Plato Corn Oil', 1230, Decimal('596.7038'))
# (1351, 'Ebony Tomatos', 809, Decimal('596.4580'))
# (1352, 'Top Measure Light Beer', 1522, Decimal('596.3682'))
# (1353, 'Choice Tasty Candy Bar', 253, Decimal('595.5880'))
# (1354, 'Just Right Fancy Canned Sardines', 974, Decimal('594.9016'))
# (1355, 'Footnote Extra Lean Hamburger', 786, Decimal('593.8049'))
# (1356, 'Imagine Beef TV Dinner', 720, Decimal('593.6322'))
# (1357, 'National Large Eggs', 1018, Decimal('593.4423'))
# (1358, 'Golden Blueberry Waffles', 88, Decimal('587.5262'))
# (1359, 'Good Light Wine', 267, Decimal('586.4614'))
# (1360, 'Fabulous Cola', 944, Decimal('586.3880'))
# (1361, 'Ebony Red Delcious Apples', 820, Decimal('586.0890'))
# (1362, 'Musial Malted Milk Balls', 1193, Decimal('585.1750'))
# (1363, 'Fantastic White Bread', 902, Decimal('582.3686'))
# (1364, 'Sunset Copper Cleaner', 1405, Decimal('581.3747'))
# (1365, 'Horatio Dried Apricots', 1189, Decimal('577.8128'))
# (1366, 'Fast Low Fat Cookies', 528, Decimal('575.9232'))
# (1367, 'Golden Frozen Cheese Pizza', 92, Decimal('575.4722'))
# (1368, 'Better Noodle Soup', 334, Decimal('574.5792'))
# (1369, 'Blue Label Turkey Noodle Soup', 26, Decimal('574.2968'))
# (1370, 'Faux Products Tartar Control Toothpaste', 114, Decimal('573.2612'))
# (1371, 'Johnson Wheat Puffs', 1263, Decimal('572.1771'))
# (1372, 'Imagine Frozen Chicken Thighs', 732, Decimal('570.6701'))
# (1373, 'Big Time Frozen Sausage Pizza', 398, Decimal('570.3840'))
# (1374, 'Pleasant Fancy Canned Clams', 1283, Decimal('569.9929'))
# (1375, 'Best Choice Cheese Crackers', 228, Decimal('568.3420'))
# (1376, 'Bravo Canned Tomatos', 644, Decimal('566.7267'))
# (1377, 'PigTail Home Style French Fries', 1039, Decimal('564.7482'))
# (1378, 'Booker Cheese Spread', 1301, Decimal('563.5582'))
# (1379, 'Horatio Potato Chips', 1163, Decimal('561.1998'))
# (1380, 'Ebony Limes', 815, Decimal('560.2708'))
# (1381, 'High Quality Large Sponge', 1100, Decimal('558.7560'))
# (1382, 'Tri-State Cauliflower', 1124, Decimal('556.9722'))
# (1383, 'Best Choice Low Fat Chips', 240, Decimal('556.0674'))
# (1384, 'Consolidated Apricot Shampoo', 743, Decimal('555.0816'))
# (1385, 'Hermanos Fancy Plums', 1449, Decimal('553.3722'))
# (1386, 'Carrington Home Style French Fries', 1350, Decimal('553.3524'))
# (1387, 'Sunset Counter Cleaner', 1392, Decimal('553.0207'))
# (1388, 'Pleasant Rice Soup', 1286, Decimal('549.5670'))
# (1389, 'Steady Childrens Cold Remedy', 440, Decimal('549.4134'))
# (1390, 'Gorilla Low Fat Sour Cream', 666, Decimal('547.3411'))
# (1391, 'Landslide Salt', 611, Decimal('543.9224'))
# (1392, 'American Beef Bologna', 1003, Decimal('543.0204'))
# (1393, 'Johnson Corn Puffs', 1262, Decimal('541.6900'))
# (1394, 'Carlson Low Fat Sour Cream', 355, Decimal('540.0675'))
# (1395, 'Even Better Head Cheese', 989, Decimal('538.2048'))
# (1396, 'Cutting Edge Sliced Ham', 696, Decimal('537.2784'))
# (1397, 'Imagine Orange Popsicles', 705, Decimal('532.5672'))
# (1398, 'Denny Plastic Forks', 133, Decimal('526.0850'))
# (1399, 'High Top Lettuce', 181, Decimal('524.6874'))
# (1400, 'PigTail Ice Cream', 1041, Decimal('524.3066'))
# (1401, 'Even Better 2% Milk', 994, Decimal('521.5817'))
# (1402, 'Fast Grape Fruit Roll', 558, Decimal('521.3040'))
# (1403, 'Even Better Sour Cream', 983, Decimal('519.8554'))
# (1404, 'Gauss Monthly Fashion Magazine', 1419, Decimal('519.7045'))
# (1405, 'Tri-State Asparagus', 1111, Decimal('517.8030'))
# (1406, 'Landslide Grape Jelly', 622, Decimal('517.2093'))
# (1407, 'Cormorant Toilet Paper', 773, Decimal('515.7582'))
# (1408, 'Discover Ravioli', 888, Decimal('514.9584'))
# (1409, 'Radius Grits', 637, Decimal('514.4606'))
# (1410, 'Black Tie Eyeglass Screwdriver', 352, Decimal('512.5098'))
# (1411, 'Big City Canned Peaches', 977, Decimal('510.4692'))
# (1412, 'Top Measure White Zinfandel Wine', 1521, Decimal('508.3890'))
# (1413, 'Queen Eyeglass Screwdriver', 41, Decimal('505.4755'))
# (1414, 'Token Apple Juice', 632, Decimal('504.7479'))
# (1415, 'Even Better Jack Cheese', 984, Decimal('504.2817'))
# (1416, 'BBB Best Tomato Sauce', 920, Decimal('503.0065'))
# (1417, 'BBB Best Pepper', 925, Decimal('502.7780'))
# (1418, 'Tip Top Lox', 215, Decimal('495.2510'))
# (1419, 'Tell Tale Fancy Plums', 511, Decimal('494.6728'))
# (1420, 'Steady Whitening Toothpast', 426, Decimal('494.1900'))
# (1421, 'Tell Tale Potatos', 496, Decimal('493.7772'))
# (1422, 'Consolidated Laundry Detergent', 752, Decimal('492.5920'))
# (1423, 'Tri-State New Potatos', 1113, Decimal('491.9944'))
# (1424, 'Shady Lake Rice Medly', 576, Decimal('490.1260'))
# (1425, 'Atomic Mint Chocolate Bar', 565, Decimal('489.5190'))
# (1426, 'Hermanos Macintosh Apples', 1445, Decimal('486.2170'))
# (1427, 'CDR Tomato Sauce', 1542, Decimal('485.6495'))
# (1428, 'King Rosy Sunglasses', 40, Decimal('481.1499'))
# (1429, 'Tell Tale Summer Squash', 482, Decimal('480.4422'))
# (1430, 'Bravo Chicken Ramen Soup', 651, Decimal('478.8240'))
# (1431, 'Tri-State Tangerines', 1151, Decimal('476.7490'))
# (1432, 'Better Turkey Noodle Soup', 337, Decimal('476.3025'))
# (1433, 'Plato Grape Preserves', 1233, Decimal('473.1422'))
# (1434, 'Pleasant Canned Beets', 1265, Decimal('471.9672'))
# (1435, 'Fabulous Cranberry Juice', 947, Decimal('466.6285'))
# (1436, 'Token Apple Drink', 633, Decimal('466.4072'))
# (1437, 'Big Time Waffles', 401, Decimal('463.6450'))
# (1438, 'Fantastic Blueberry Muffins', 908, Decimal('462.7830'))
# (1439, 'Lake Turkey Hot Dogs', 1316, Decimal('462.1745'))
# (1440, 'Tell Tale Lemons', 510, Decimal('460.8733'))
# (1441, 'Carlson Whole Milk', 371, Decimal('460.5546'))
# (1442, 'Tri-State Garlic', 1122, Decimal('458.9924'))
# (1443, 'Consolidated Extra Moisture Shampoo', 741, Decimal('457.5129'))
# (1444, 'Better Chicken Ramen Soup', 340, Decimal('455.2632'))
# (1445, 'Top Measure Merlot Wine', 1519, Decimal('454.5477'))
# (1446, 'Fort West Cheese Dip', 1484, Decimal('454.3308'))
# (1447, 'Best Choice Lemon Cookies', 226, Decimal('453.8948'))
# (1448, 'Club Strawberry Yogurt', 61, Decimal('442.5644'))
# (1449, 'Best Choice Low Fat Cookies', 217, Decimal('441.9728'))
# (1450, 'Tri-State Canned Peanuts', 1144, Decimal('440.8015'))
# (1451, 'Carrington Orange Popsicles', 1332, Decimal('439.6611'))
# (1452, 'Walrus Chardonnay Wine', 579, Decimal('438.7795'))
# (1453, 'Golden Waffles', 90, Decimal('438.4919'))
# (1454, 'Landslide Strawberry Jelly', 608, Decimal('437.0496'))
# (1455, 'Hermanos Tangerines', 1462, Decimal('436.8831'))
# (1456, 'Hilltop Childrens Cold Remedy', 1378, Decimal('432.8608'))
# (1457, 'Carrington Blueberry Waffles', 1337, Decimal('432.3051'))
# (1458, 'Token Diet Cola', 629, Decimal('429.9350'))
# (1459, 'CDR Low Fat Apple Butter', 1548, Decimal('429.4834'))
# (1460, 'Fast Golden Raisins', 561, Decimal('428.4357'))
# (1461, 'Choice Malted Milk Balls', 255, Decimal('427.7952'))
# (1462, 'Club 2% Milk', 56, Decimal('425.9361'))
# (1463, 'Washington Strawberry Drink', 3, Decimal('424.8438'))
# (1464, 'CDR Apple Preserves', 1559, Decimal('424.2456'))
# (1465, 'Golden Chicken TV Dinner', 97, Decimal('423.1244'))
# (1466, 'Excel Monthly Computer Magazine', 790, Decimal('421.6828'))
# (1467, 'Even Better Muenster Cheese', 985, Decimal('420.1200'))
# (1468, 'Pearl Chardonnay Wine', 895, Decimal('419.5165'))
# (1469, 'Fabulous Berry Juice', 939, Decimal('417.6550'))
# (1470, 'Johnson Oatmeal', 1261, Decimal('416.5620'))
# (1471, 'Booker Large Curd Cottage Cheese', 1304, Decimal('416.3380'))
# (1472, 'Fast Low Fat BBQ Chips', 531, Decimal('414.3900'))
# (1473, 'Gorilla Blueberry Yogurt', 684, Decimal('413.9024'))
# (1474, 'Golden Apple Cinnamon Waffles', 94, Decimal('412.6286'))
# (1475, 'Red Spade Potato Salad', 75, Decimal('409.9856'))
# (1476, 'Washington Mango Drink', 2, Decimal('409.6048'))
# (1477, 'Plato Hot Chocolate', 1223, Decimal('409.3302'))
# (1478, 'Fantastic Muffins', 906, Decimal('408.5613'))
# (1479, 'Sunset Silver Cleaner', 1407, Decimal('406.4571'))
# (1480, 'Fort West Avocado Dip', 1482, Decimal('405.9840'))
# (1481, 'Landslide Hot Chocolate', 596, Decimal('404.9472'))
# (1482, 'Red Wing Large Sponge', 473, Decimal('404.4346'))
# (1483, 'High Top Broccoli', 203, Decimal('403.1307'))
# (1484, 'Faux Products Whitening Toothpast', 115, Decimal('402.3175'))
# (1485, 'Faux Products Multi-Symptom Cold Remedy', 128, Decimal('402.0686'))
# (1486, 'Red Wing Paper Towels', 459, Decimal('401.8368'))
# (1487, 'Just Right Chicken Ramen Soup', 967, Decimal('401.5813'))
# (1488, 'Imagine Frozen Sausage Pizza', 709, Decimal('400.8012'))
# (1489, 'Nationeel Low Fat Cookies', 839, Decimal('400.2900'))
# (1490, 'High Top Tangerines', 213, Decimal('399.9632'))
# (1491, 'Red Wing Scissors', 472, Decimal('399.0940'))
# (1492, 'Skinner Apple Drink', 1260, Decimal('398.1006'))
# (1493, 'Landslide Extra Chunky Peanut Butter', 620, Decimal('398.0252'))
# (1494, 'PigTail Grape Popsicles', 1038, Decimal('397.9276'))
# (1495, 'Golden Home Style French Fries', 101, Decimal('395.8920'))
# (1496, 'Booker Mild Cheddar Cheese', 1303, Decimal('395.1888'))
# (1497, 'Hilltop Toothpaste', 1365, Decimal('394.4684'))
# (1498, 'High Top Shitake Mushrooms', 180, Decimal('392.2581'))
# (1499, 'BBB Best Salt', 927, Decimal('390.2094'))
# (1500, 'Club Buttermilk', 57, Decimal('386.7522'))
# (1501, 'Denny D-Size Batteries', 147, Decimal('386.3232'))
# (1502, 'Steady Deodorant', 428, Decimal('385.9669'))
# (1503, 'Nationeel No Salt Popcorn', 852, Decimal('384.4818'))
# (1504, 'Super Apple Butter', 301, Decimal('384.2235'))
# (1505, 'Robust Monthly Auto Magazine', 167, Decimal('383.0220'))
# (1506, 'High Top Potatos', 185, Decimal('382.9431'))
# (1507, 'Imagine Lemon Popsicles', 734, Decimal('380.9736'))
# (1508, 'Dual City Lox', 1153, Decimal('380.7544'))
# (1509, 'Sunset Economy Toilet Brush', 1409, Decimal('380.6884'))
# (1510, 'Better Canned Beets', 327, Decimal('376.6260'))
# (1511, 'Bird Call Mint Mouthwash', 1069, Decimal('373.0251'))
# (1512, 'Choice Mint Chocolate Bar', 254, Decimal('372.5064'))
# (1513, 'Steady Laundry Detergent', 441, Decimal('371.5545'))
# (1514, 'Tell Tale Peaches', 513, Decimal('370.5388'))
# (1515, 'BBB Best Oregano', 929, Decimal('369.9983'))
# (1516, 'Moms Sliced Turkey', 384, Decimal('368.3826'))
# (1517, 'American Sliced Chicken', 1014, Decimal('367.0803'))
# (1518, 'PigTail Pancake Mix', 1037, Decimal('366.8616'))
# (1519, 'Carrington Frozen Broccoli', 1355, Decimal('360.5805'))
# (1520, 'Jumbo Small Eggs', 701, Decimal('360.4500'))
# (1521, 'Cormorant D-Size Batteries', 769, Decimal('360.4487'))
# (1522, 'Big Time Grape Popsicles', 411, Decimal('359.6163'))
# (1523, 'Lake Beef Bologna', 1314, Decimal('357.8816'))
# (1524, 'High Quality 25 Watt Lightbulb', 1083, Decimal('354.9550'))
# (1525, 'Cormorant Glass Cleaner', 766, Decimal('353.8278'))
# (1526, 'CDR Strawberry Jelly', 1546, Decimal('352.7813'))
# (1527, 'Gorilla Whole Milk', 682, Decimal('351.3905'))
# (1528, 'Pearl Light Wine', 894, Decimal('350.9946'))
# (1529, 'Excel Monthly Sports Magazine', 788, Decimal('346.9235'))
# (1530, 'Skinner Cranberry Juice', 1258, Decimal('346.2177'))
# (1531, 'Cormorant Large Sponge', 784, Decimal('345.0200'))
# (1532, 'Atomic Tasty Candy Bar', 564, Decimal('343.8534'))
# (1533, 'Bird Call HCL Nasal Spray', 1064, Decimal('343.8450'))
# (1534, 'Imagine Home Style French Fries', 723, Decimal('342.3936'))
# (1535, 'Pearl Merlot Wine', 897, Decimal('341.7336'))
# (1536, 'Denny Glass Cleaner', 144, Decimal('341.3022'))
# (1537, 'Sphinx Pumpernickel Bread', 1212, Decimal('340.5197'))
# (1538, 'Better Beef Soup', 338, Decimal('336.8757'))
# (1539, 'Jardon Rice Medly', 1514, Decimal('335.9940'))
# (1540, 'Booker 2% Milk', 1305, Decimal('333.1878'))
# (1541, 'Super Columbian Coffee', 296, Decimal('324.7000'))
# (1542, 'Fast Dried Apricots', 562, Decimal('324.0280'))
# (1543, 'PigTail Apple Cinnamon Waffles', 1032, Decimal('323.4055'))
# (1544, 'Landslide Sesame Oil', 594, Decimal('320.4906'))
# (1545, 'Modell Wheat Bread', 1531, Decimal('319.7496'))
# (1546, 'Club Sour Cream', 45, Decimal('318.8586'))
# (1547, 'Denny Copper Cleaner', 156, Decimal('318.7250'))
# (1548, 'PigTail Low Fat Waffles', 1020, Decimal('316.7661'))
# (1549, 'Ebony Mushrooms', 810, Decimal('316.6521'))
# (1550, 'Fast Sesame Crackers', 552, Decimal('316.6405'))
# (1551, 'BBB Best Low Fat Apple Butter', 926, Decimal('316.3272'))
# (1552, 'Tri-State Summer Squash', 1109, Decimal('313.5000'))
# (1553, 'Bird Call Silky Smooth Hair Conditioner', 1051, Decimal('312.5616'))
# (1554, 'Sunset Bees Wax Candles', 1406, Decimal('305.2728'))
# (1555, 'Fast Buttered Popcorn', 540, Decimal('302.3535'))
# (1556, 'Jardon Spaghetti', 1512, Decimal('301.9464'))
# (1557, 'Plato Columbian Coffee', 1234, Decimal('301.0112'))
# (1558, 'Top Measure Chardonnay Wine', 1517, Decimal('274.5024'))
# (1559, 'Choice Bubble Gum', 257, Decimal('259.5516'))

# %% [markdown]
# ### 8 - Which customers spent the most money in stores in 1998? List the top 20 highest spenders and the products they purchased the most.

# %%
query8 =  """ 
SELECT
    c.customer_id AS "Customer ID",
    c.account_num AS "Account Number",
    c.fname || ' ' || c.lname AS "Full Name",
    SUM(s.store_sales * s.unit_sales) AS "Total Expenditure",
    p.product_name AS "Most Purchased Product Name",
    p.product_id AS "Most Purchased Product ID"
FROM
    sales s
JOIN
    time_by_day t ON s.time_id = t.time_id
JOIN
    customer c ON s.customer_id = c.customer_id
JOIN
    product p ON s.product_id = p.product_id
WHERE
    t.the_date BETWEEN '1998-01-01' AND '1998-12-31'
GROUP BY
    c.customer_id, c.account_num, c.fname, c.lname, p.product_name, p.product_id
ORDER BY
    "Total Expenditure" DESC
LIMIT 20;
"""
cur.execute(query8)
rows = cur.fetchall()
column_titles = [desc[0] for desc in cur.description]
print(column_titles)
for row in rows:
    print(row)
# Out:
# ['Customer ID', 'Account Number', 'Full Name', 'Total Expenditure', 'Most Purchased Product Name', 'Most Purchased Product ID']
# (1297, 12041890621, 'Joann Mramor', Decimal('247.50'), 'Red Wing Plastic Knives', 446)
# (10281, 87460163235, 'Samuel Cartney', Decimal('198.64'), 'Tell Tale Cantelope', 519)
# (6047, 47643955900, 'Alice William', Decimal('188.16'), 'Imagine Frozen Carrots', 717)
# (10277, 87439274191, 'Fran Ross', Decimal('184.50'), 'Red Wing AAA-Size Batteries', 449)
# (10277, 87439274191, 'Fran Ross', Decimal('183.50'), 'Skinner Diet Soda', 1254)
# (8242, 66564966440, 'James Adams', Decimal('181.00'), 'Hilltop Mint Mouthwash', 1380)
# (8345, 67479980587, 'Harriet Gomez', Decimal('174.50'), 'Carlson 2% Milk', 367)
# (9887, 83447052836, 'Marian Campanelli', Decimal('173.28'), 'Medalist Rice Medly', 265)
# (6912, 55050822500, 'Abbie Carlbon', Decimal('171.41'), 'Hermanos Fresh Lima Beans', 1440)
# (5114, 40089884400, 'Randee Simmons', Decimal('163.50'), 'Modell Bagels', 1529)
# (1425, 12928881000, 'Lynn Williams', Decimal('162.36'), 'Carlson Mild Cheddar Cheese', 365)
# (1217, 11585722000, 'Manuel Haskin', Decimal('161.95'), 'Best Choice Chocolate Chip Cookies', 222)
# (5512, 43143096566, 'Rita Cortese', Decimal('159.49'), 'Best Choice Potato Chips', 225)
# (2237, 18571680188, 'Daryl Kannisto', Decimal('159.08'), 'Fort West BBQ Potato Chips', 1467)
# (8242, 66564966440, 'James Adams', Decimal('157.00'), 'Fast Dried Apples', 554)
# (9895, 83488112092, 'Delia Cody', Decimal('156.21'), 'Cormorant Toilet Bowl Cleaner', 764)
# (4956, 38822819600, 'Carolyn Arellano', Decimal('154.98'), 'Horatio Low Fat Chips', 1178)
# (1871, 15921952724, 'Virginia Kriete', Decimal('154.98'), 'Horatio Sugar Cookies', 1159)
# (1770, 15144621729, 'Isaiah Heymsfield', Decimal('152.52'), 'Golden Frozen Cauliflower', 105)
# (1185, 11374637500, 'Mimi Springer', Decimal('152.10'), 'Medalist Ravioli', 261)

# %% [markdown]
# ### 9 - What are the top 5 main customer groups based on gender, income, education level, and marital status?

# %%
query9 = """

SELECT 
    gender,
    yearly_income,
    education,
    marital_status,
    COUNT(*) AS customer_count
FROM 
    customer
GROUP BY 
    gender, yearly_income, education, marital_status
ORDER BY 
    customer_count DESC
LIMIT 5;
"""
cur.execute(query9)
result9 = cur.fetchall()
column_titles = [desc[0] for desc in cur.description]
print(column_titles)
for row in result9:
    print(row)
# Out:
# ['gender', 'yearly_income', 'education', 'marital_status', 'customer_count']
# ('M', '$30K - $50K', 'High School Degree', 'M', 545)
# ('F', '$30K - $50K', 'High School Degree', 'S', 535)
# ('M', '$30K - $50K', 'High School Degree', 'S', 532)
# ('M', '$10K - $30K', 'Partial High School', 'S', 524)
# ('F', '$10K - $30K', 'Partial High School', 'M', 519)

# %% [markdown]
# ### 10 - What is the most popular product among consumers of different membership levels in 1998 (the product with the most total units sold)?

# %%
query10 = """
WITH RankedProducts AS (
    SELECT 
        c.member_card AS membership_level,
        p.product_id AS id,
        p.product_name AS name,
        c.education AS customer_education,
        SUM(s.unit_sales) AS total_units,
        RANK() OVER (PARTITION BY c.member_card ORDER BY SUM(s.unit_sales) DESC) AS rank
    FROM 
        sales s
    JOIN 
        product p ON s.product_id = p.product_id
    JOIN 
        customer c ON s.customer_id = c.customer_id
    JOIN 
        time_by_day t ON s.time_id = t.time_id
    WHERE 
        t.the_date BETWEEN '1998-01-01' AND '1998-12-31'
    GROUP BY 
        c.member_card, p.product_id, c.education
)
SELECT 
    membership_level,
    id,
    name,
    customer_education,
    total_units
FROM 
    RankedProducts
WHERE 
    rank = 1
ORDER BY 
    membership_level, total_units DESC;

"""

cur.execute(query10)
result10 = cur.fetchall()
column_titles = [desc[0] for desc in cur.description]
print(column_titles)
for row in result10:
    print(row)
# Out:
# ['membership_level', 'id', 'name', 'customer_education', 'total_units']
# ('Bronze', 221, 'Best Choice Sugar Cookies', 'Bachelors Degree', 118)
# ('Golden', 444, 'Red Wing Plastic Forks', 'High School Degree', 56)
# ('Normal', 1337, 'Carrington Blueberry Waffles', 'Partial High School', 119)
# ('Silver', 1416, 'Gauss Monthly Auto Magazine', 'Bachelors Degree', 33)
# ('Silver', 753, 'Consolidated Mint Mouthwash', 'High School Degree', 33)
